# %%
import xml.etree.ElementTree as etree
import codecs
import csv
import time
import os
import re
import gzip
import bz2

# %%
PATH_WIKI_XML = '/media/andrii/earth/Katia/CS_MasterThesis/data/enwiki/en_xml_dump/'
PATH_WIKI_OUT = '/media/andrii/earth/Katia/CS_MasterThesis/data/enwiki/en_parsed/'

# %%
WIKI_FILENAMES = []
for file in os.listdir(PATH_WIKI_XML):
    if file.endswith(".bz2"):
        WIKI_FILENAMES.append(file)

# %%
WIKI_FILENAMES
# Out:
# ['enwiki-20180920-pages-meta-current4.xml-p200511p352689.bz2',
#  'enwiki-20180920-pages-meta-current25.xml-p35452816p36952816.bz2',
#  'enwiki-20180920-pages-meta-current17.xml-p11539268p13039268.bz2',
#  'enwiki-20180920-pages-meta-current6.xml-p565314p892912.bz2',
#  'enwiki-20180920-pages-meta-current16.xml-p11018050p11539266.bz2',
#  'enwiki-20180920-pages-meta-current27.xml-p57663462p58534506.bz2',
#  'enwiki-20180920-pages-meta-current25.xml-p36952816p38067202.bz2',
#  'enwiki-20180920-pages-meta-current25.xml-p33952816p35452816.bz2',
#  'enwiki-20180920-pages-meta-current22.xml-p25427984p26823660.bz2',
#  'enwiki-20180920-pages-meta-current11.xml-p3046514p3926861.bz2',
#  'enwiki-20180920-pages-meta-current13.xml-p5040438p6197594.bz2',
#  'enwiki-20180920-pages-meta-current26.xml-p39567203p41067203.bz2',
#  'enwiki-20180920-pages-meta-current17.xml-p13039268p13693071.bz2',
#  'enwiki-20180920-pages-meta-current20.xml-p20254736p21222156.bz2',
#  'enwiki-20180920-pages-meta-current5.xml-p352690p565313.bz2',
#  'enwiki-20180920-pages-meta-current10.xml-p2336425p3046511.bz2',
#  'enwiki-20180920-pages-meta-current15.xml-p9244803p9518048.bz2',
#  'enwiki-20180920-pages-meta-current23.xml-p26823661p28323661.bz2',
#  'enwiki-20180920-pages-meta-current14.xml-p7697598p7744799.bz2',
#  'enwiki-20180920-pages-meta-current21.xml-p21222158p22722158.bz2',
#  'enwiki-20180920-pages-meta-current9.xml-p1791080p2336422.bz2',
#  'enwiki-20180920-pages-meta-current18.xml-p15193074p16120542.bz2',
#  'enwiki-20180920-pages-meta-current8.xml-p1268692p1791079.bz2',
#  'enwiki-20180920-pages-meta-current15.xml-p7744803p9244803.bz2',
#  'enwiki-20180920-pages-meta-current1.xml-p10p30303.bz2',
#  'enwiki-20180920-pages-meta-current12.xml-p3926863p5040436.bz2',
#  'enwiki-20180920-pages-meta-current27.xml-p45663462p47163462.bz2',
#  'enwiki-20180920-pages-meta-current22.xml-p23927984p25427984.bz2',
#  'enwiki-20180920-pages-meta-current3.xml-p88445p200507.bz2',
#  'enwiki-20180920-pages-meta-current27.xml-p51663462p53163462.bz2',
#  'enwiki-20180920-pages-meta-current27.xml-p42663462p44163462.bz2',
#  'enwiki-20180920-pages-meta-current27.xml-p56163462p57663462.bz2',
#  'enwiki-20180920-pages-meta-current16.xml-p9518050p11018050.bz2',
#  'enwiki-20180920-pages-meta-current26.xml-p41067203p42567203.bz2',
#  'enwiki-20180920-pages-meta-current27.xml-p48663462p50163462.bz2',
#  'enwiki-20180920-pages-meta-current27.xml-p53163462p54663462.bz2',
#  'enwiki-20180920-pages-meta-current21.xml-p22722158p23927983.bz2',
#  'enwiki-20180920-pages-meta-current26.xml-p38067203p39567203.bz2',
#  'enwiki-20180920-pages-meta-current27.xml-p54663462p56163462.bz2',
#  'enwiki-20180920-pages-meta-current24.xml-p33503451p33952815.bz2',
#  'enwiki-20180920-pages-meta-current24.xml-p30503451p32003451.bz2',
#  'enwiki-20180920-pages-meta-current27.xml-p47163462p48663462.bz2',
#  'enwiki-20180920-pages-meta-current19.xml-p16120543p17620543.bz2',
#  'enwiki-20180920-pages-meta-current20.xml-p18754736p20254736.bz2',
#  'enwiki-20180920-pages-meta-current2.xml-p30304p88444.bz2',
#  'enwiki-20180920-pages-meta-current24.xml-p32003451p33503451.bz2',
#  'enwiki-20180920-pages-meta-current18.xml-p13693074p15193074.bz2',
#  'enwiki-20180920-pages-meta-current26.xml-p42567203p42663461.bz2',
#  'enwiki-20180920-pages-meta-current27.xml-p50163462p51663462.bz2',
#  'enwiki-20180920-pages-meta-current14.xml-p6197598p7697598.bz2',
#  'enwiki-20180920-pages-meta-current27.xml-p44163462p45663462.bz2',
#  'enwiki-20180920-pages-meta-current7.xml-p892914p1268691.bz2',
#  'enwiki-20180920-pages-meta-current23.xml-p28323661p29823661.bz2',
#  'enwiki-20180920-pages-meta-current23.xml-p29823661p30503449.bz2',
#  'enwiki-20180920-pages-meta-current19.xml-p17620543p18754735.bz2']

# %%
len(WIKI_FILENAMES)
# Out:
# 55

# %%
def unpack(file_name):
    file_name_new = file_name.replace(".bz2","")
    with bz2.open(file_name, 'rb') as f_in, open(file_name_new, 'wb') as f_out:
        f_out.writelines(f_in)
    return file_name_new

# %%
def pack_and_remove(file_name):
    file_name_new = file_name+'.bz2'
    with open(file_name, 'rb') as f_in, bz2.open(file_name_new, 'wb') as f_out:
        f_out.writelines(f_in)
    os.remove(file_name)
    return file_name_new

# %%
ENCODING = "utf-8"

# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)


def strip_tag_name(t):
    t = elem.tag
    idx = k = t.rfind("}")
    if idx != -1:
        t = t[idx + 1:]
    return t


totalCount = 0
articleCount = 0
redirectCount = 0
total_article_text_len = 0

# %%
start_time = time.time()
regex_links = re.compile(r"\[\[(?P<article>(?!.*?\:).*?)(?:\{\{.*\}\})?(?:\|(?P<text>(?!.*?\:).*?))?\]\]")
for WikiXML in WIKI_FILENAMES:
    pathWikiXML = os.path.join(PATH_WIKI_XML, WikiXML)
    pathWikiXML = unpack(pathWikiXML)
    pathArticles = os.path.join(PATH_WIKI_OUT, WikiXML+"_art.csv")
    pathArticlesRedirect = os.path.join(PATH_WIKI_OUT, WikiXML+"_red.csv")
    with codecs.open(pathArticles, "w", ENCODING) as articlesFH, \
    codecs.open(pathArticlesRedirect, "w", ENCODING) as redirectFH:
        articlesWriter = csv.writer(articlesFH, quoting=csv.QUOTE_MINIMAL)
        articlesWriter.writerow(['id', 'title', 'text_len', 'link_pos', 'link_val', 'link_txt']) 
        redirectWriter = csv.writer(redirectFH, quoting=csv.QUOTE_MINIMAL)
        redirectWriter.writerow(['id', 'title', 'redirect'])
        for event, elem in etree.iterparse(pathWikiXML, events=('start', 'end')):
            tname = strip_tag_name(elem.tag)

            if event == 'start':
                if tname == 'page':
                    title = ''
                    id = -1
                    redirect = ''
                    inrevision = False
                    ns = 0
                    article_text_len = 0
                    links = []
                elif tname == 'revision':
                    # Do not pick up on revision id's
                    inrevision = True
            else:
                if tname == 'title':
                    title = elem.text
                elif tname == 'id' and not inrevision:
                    id = int(elem.text)
                elif tname == 'redirect':
                    redirect = elem.attrib['title']
                elif tname == 'ns':
                    ns = int(elem.text)
                elif tname == 'page' and ns == 0:
                    totalCount += 1
                    total_article_text_len += article_text_len                        
                    if len(redirect) == 0:
                        articleCount += 1
                        if len(links) == 0:
                            articlesWriter.writerow([id, title, article_text_len, 0, "", ""])
                        for link in links:
                            articlesWriter.writerow([id, title, article_text_len, link[0], link[1], link[2]])
                    else:
                        redirectCount += 1
                        redirectWriter.writerow([id, title, redirect])

                    if totalCount > 1 and (totalCount % 100000) == 0:
                        print("{:,}".format(totalCount))
                elif tname == 'text' and elem.text != None:
                    article_text_len = len(elem.text)
                    for match in regex_links.finditer(elem.text):    
                        link_pos = match.start()
                        link_title = match.group("article")
                        link_title = link_title.replace("&nbsp;", " ")
                        link_title = link_title.replace("&ndash;", "-")
                        link_title = link_title.replace("&mdash;", "—")
                        link_title = link_title.replace("%20", " ")
                        
                        link_text = match.group("text")
                        links.append((link_pos,link_title,link_text))


                elem.clear()
    
    fn_in = pathArticles
    with open(fn_in, 'rb') as f_in, gzip.open(fn_in+'.gz', 'wb') as f_out:
        f_out.writelines(f_in)
    os.remove(fn_in)
    
    fn_in = pathArticlesRedirect
    with open(fn_in, 'rb') as f_in, gzip.open(fn_in+'.gz', 'wb') as f_out:
        f_out.writelines(f_in)
    os.remove(fn_in)
    
    elapsed_time = time.time() - start_time
    print("File processed: {}".format(WikiXML))
    print("Total pages: {:,}".format(totalCount))
    print("Article pages: {:,}".format(articleCount))
    print("Redirect pages: {:,}".format(redirectCount))
    print("Total article lenght: {:,}".format(total_article_text_len))
    print("Elapsed time: {}".format(hms_string(elapsed_time)))

elapsed_time = time.time() - start_time

print("Total pages: {:,}".format(totalCount))
print("Article pages: {:,}".format(articleCount))
print("Redirect pages: {:,}".format(redirectCount))
print("Total article lenght: {:,}".format(total_article_text_len))
print("Elapsed time: {}".format(hms_string(elapsed_time)))
# Out:
# File processed: enwiki-20180920-pages-meta-current4.xml-p200511p352689.bz2
# Total pages: 83,431
# Article pages: 49,105
# Redirect pages: 34,326
# Total article lenght: 901,000,754
# Elapsed time: 0:02:36.78
# 100,000
# 200,000
# 300,000
# 400,000
# File processed: enwiki-20180920-pages-meta-current25.xml-p35452816p36952816.bz2
# Total pages: 447,965
# Article pages: 200,231
# Redirect pages: 247,734
# Total article lenght: 1,753,971,854
# Elapsed time: 0:09:21.83
# 500,000
# 600,000
# 700,000
# 800,000
# File processed: enwiki-20180920-pages-meta-current17.xml-p11539268p13039268.bz2
# Total pages: 834,646
# Article pages: 372,737
# Redirect pages: 461,909
# Total article lenght: 2,696,607,618
# Elapsed time: 0:15:39.40
# 900,000
# 1,000,000
# File processed: enwiki-20180920-pages-meta-current6.xml-p565314p892912.bz2
# Total pages: 1,011,646
# Article pages: 450,906
# Redirect pages: 560,740
# Total article lenght: 3,732,392,156
# Elapsed time: 0:18:59.53
# 1,100,000
# File processed: enwiki-20180920-pages-meta-current16.xml-p11018050p11539266.bz2
# Total pages: 1,119,329
# Article pages: 497,247
# Redirect pages: 622,082
# Total article lenght: 4,035,646,942
# Elapsed time: 0:21:03.15
# 1,200,000
# File processed: enwiki-20180920-pages-meta-current27.xml-p57663462p58534506.bz2
# Total pages: 1,290,743
# Article pages: 557,157
# Redirect pages: 733,586
# Total article lenght: 4,361,912,009
# Elapsed time: 0:24:40.90
# 1,300,000
# 1,400,000
# 1,500,000
# File processed: enwiki-20180920-pages-meta-current25.xml-p36952816p38067202.bz2
# Total pages: 1,546,413
# Article pages: 652,778
# Redirect pages: 893,635
# Total article lenght: 4,941,886,527
# Elapsed time: 0:29:33.10
# 1,600,000
# 1,700,000
# 1,800,000
# File processed: enwiki-20180920-pages-meta-current25.xml-p33952816p35452816.bz2
# Total pages: 1,862,622
# Article pages: 766,216
# Redirect pages: 1,096,406
# Total article lenght: 5,631,017,916
# Elapsed time: 0:35:50.20
# 1,900,000
# 2,000,000
# 2,100,000
# File processed: enwiki-20180920-pages-meta-current22.xml-p25427984p26823660.bz2
# Total pages: 2,166,636
# Article pages: 889,065
# Redirect pages: 1,277,571
# Total article lenght: 6,374,764,277
# Elapsed time: 0:42:05.69
# 2,200,000
# 2,300,000
# 2,400,000
# File processed: enwiki-20180920-pages-meta-current11.xml-p3046514p3926861.bz2
# Total pages: 2,448,359
# Article pages: 1,022,181
# Redirect pages: 1,426,178
# Total article lenght: 7,476,345,078
# Elapsed time: 0:47:06.68
# 2,500,000
# 2,600,000
# 2,700,000
# File processed: enwiki-20180920-pages-meta-current13.xml-p5040438p6197594.bz2
# Total pages: 2,779,254
# Article pages: 1,169,915
# Redirect pages: 1,609,339
# Total article lenght: 8,554,173,792
# Elapsed time: 0:52:52.17
# 2,800,000
# 2,900,000
# 3,000,000
# 3,100,000
# File processed: enwiki-20180920-pages-meta-current26.xml-p39567203p41067203.bz2
# Total pages: 3,117,042
# Article pages: 1,310,542
# Redirect pages: 1,806,500
# Total article lenght: 9,401,879,888
# Elapsed time: 0:59:33.66
# 3,200,000
# File processed: enwiki-20180920-pages-meta-current17.xml-p13039268p13693071.bz2
# Total pages: 3,269,457
# Article pages: 1,373,146
# Redirect pages: 1,896,311
# Total article lenght: 9,746,736,827
# Elapsed time: 1:02:13.52
# 3,300,000
# 3,400,000
# File processed: enwiki-20180920-pages-meta-current20.xml-p20254736p21222156.bz2
# Total pages: 3,464,360
# Article pages: 1,459,102
# Redirect pages: 2,005,258
# Total article lenght: 10,254,826,485
# Elapsed time: 1:06:15.60
# 3,500,000
# File processed: enwiki-20180920-pages-meta-current5.xml-p352690p565313.bz2
# Total pages: 3,583,773
# Article pages: 1,524,061
# Redirect pages: 2,059,712
# Total article lenght: 11,226,384,729
# Elapsed time: 1:09:12.70
# 3,600,000
# 3,700,000
# 3,800,000
# File processed: enwiki-20180920-pages-meta-current10.xml-p2336425p3046511.bz2
# Total pages: 3,834,246
# Article pages: 1,647,096
# Redirect pages: 2,187,150
# Total article lenght: 12,285,749,069
# Elapsed time: 1:13:34.73
# File processed: enwiki-20180920-pages-meta-current15.xml-p9244803p9518048.bz2
# Total pages: 3,891,794
# Article pages: 1,671,406
# Redirect pages: 2,220,388
# Total article lenght: 12,450,794,729
# Elapsed time: 1:14:39.96
# 3,900,000
# 4,000,000
# 4,100,000
# 4,200,000
# File processed: enwiki-20180920-pages-meta-current23.xml-p26823661p28323661.bz2
# Total pages: 4,252,545
# Article pages: 1,810,344
# Redirect pages: 2,442,201
# Total article lenght: 13,261,537,296
# Elapsed time: 1:21:12.73
# File processed: enwiki-20180920-pages-meta-current14.xml-p7697598p7744799.bz2
# Total pages: 4,262,653
# Article pages: 1,814,895
# Redirect pages: 2,447,758
# Total article lenght: 13,291,889,943
# Elapsed time: 1:21:24.23
# 4,300,000
# 4,400,000
# 4,500,000
# 4,600,000
# File processed: enwiki-20180920-pages-meta-current21.xml-p21222158p22722158.bz2
# Total pages: 4,620,794
# Article pages: 1,969,950
# Redirect pages: 2,650,844
# Total article lenght: 14,116,101,206
# Elapsed time: 1:29:09.11
# 4,700,000
# 4,800,000
# File processed: enwiki-20180920-pages-meta-current9.xml-p1791080p2336422.bz2
# Total pages: 4,848,000
# Article pages: 2,076,706
# Redirect pages: 2,771,294
# Total article lenght: 15,172,293,143
# Elapsed time: 1:33:08.55
# 4,900,000
# 5,000,000
# File processed: enwiki-20180920-pages-meta-current18.xml-p15193074p16120542.bz2
# Total pages: 5,054,192
# Article pages: 2,174,486
# Redirect pages: 2,879,706
# Total article lenght: 15,651,347,099
# Elapsed time: 1:36:54.73
# 5,100,000
# 5,200,000
# File processed: enwiki-20180920-pages-meta-current8.xml-p1268692p1791079.bz2
# Total pages: 5,272,073
# Article pages: 2,279,519
# Redirect pages: 2,992,554
# Total article lenght: 16,747,826,304
# Elapsed time: 1:40:53.92
# 5,300,000
# 5,400,000
# 5,500,000
# 5,600,000
# File processed: enwiki-20180920-pages-meta-current15.xml-p7744803p9244803.bz2
# Total pages: 5,607,936
# Article pages: 2,419,979
# Redirect pages: 3,187,957
# Total article lenght: 17,709,725,783
# Elapsed time: 1:47:04.25
# File processed: enwiki-20180920-pages-meta-current1.xml-p10p30303.bz2
# Total pages: 5,627,655
# Article pages: 2,435,020
# Redirect pages: 3,192,635
# Total article lenght: 18,301,208,762
# Elapsed time: 1:48:26.98
# 5,700,000
# 5,800,000
# 5,900,000
# File processed: enwiki-20180920-pages-meta-current12.xml-p3926863p5040436.bz2
# Total pages: 5,944,911
# Article pages: 2,580,274
# Redirect pages: 3,364,637
# Total article lenght: 19,426,021,249
# Elapsed time: 1:54:06.61
# 6,000,000
# 6,100,000
# File processed: enwiki-20180920-pages-meta-current27.xml-p45663462p47163462.bz2
# Total pages: 6,180,742
# Article pages: 2,670,858
# Redirect pages: 3,509,884
# Total article lenght: 20,014,947,552
# Elapsed time: 2:00:33.76
# 6,200,000
# 6,300,000
# 6,400,000
# 6,500,000
# File processed: enwiki-20180920-pages-meta-current22.xml-p23927984p25427984.bz2
# Total pages: 6,520,792
# Article pages: 2,814,601
# Redirect pages: 3,706,191
# Total article lenght: 20,860,226,863
# Elapsed time: 2:07:22.47
# 6,600,000
# File processed: enwiki-20180920-pages-meta-current3.xml-p88445p200507.bz2
# Total pages: 6,602,706
# Article pages: 2,880,127
# Redirect pages: 3,722,579
# Total article lenght: 21,987,136,650
# Elapsed time: 2:10:14.92
# 6,700,000
# 6,800,000
# File processed: enwiki-20180920-pages-meta-current27.xml-p51663462p53163462.bz2
# Total pages: 6,895,004
# Article pages: 2,991,928
# Redirect pages: 3,903,076
# Total article lenght: 22,659,260,178
# Elapsed time: 2:18:00.68
# 6,900,000
# 7,000,000
# 7,100,000
# 7,200,000
# File processed: enwiki-20180920-pages-meta-current27.xml-p42663462p44163462.bz2
# Total pages: 7,270,454
# Article pages: 3,131,824
# Redirect pages: 4,138,630
# Total article lenght: 23,494,354,730
# Elapsed time: 2:24:46.50
# 7,300,000
# 7,400,000
# 7,500,000
# 7,600,000
# File processed: enwiki-20180920-pages-meta-current27.xml-p56163462p57663462.bz2
# Total pages: 7,604,590
# Article pages: 3,264,885
# Redirect pages: 4,339,705
# Total article lenght: 24,251,722,053
# Elapsed time: 2:31:36.70
# 7,700,000
# 7,800,000
# File processed: enwiki-20180920-pages-meta-current16.xml-p9518050p11018050.bz2
# Total pages: 7,879,246
# Article pages: 3,384,110
# Redirect pages: 4,495,136
# Total article lenght: 25,048,875,516
# Elapsed time: 2:37:36.37
# 7,900,000
# 8,000,000
# 8,100,000
# 8,200,000
# File processed: enwiki-20180920-pages-meta-current26.xml-p41067203p42567203.bz2
# Total pages: 8,218,532
# Article pages: 3,524,948
# Redirect pages: 4,693,584
# Total article lenght: 25,878,885,337
# Elapsed time: 2:44:33.86
# 8,300,000
# 8,400,000
# 8,500,000
# File processed: enwiki-20180920-pages-meta-current27.xml-p48663462p50163462.bz2
# Total pages: 8,587,367
# Article pages: 3,634,276
# Redirect pages: 4,953,091
# Total article lenght: 26,571,923,553
# Elapsed time: 2:50:49.57
# 8,600,000
# 8,700,000
# 8,800,000
# 8,900,000
# File processed: enwiki-20180920-pages-meta-current27.xml-p53163462p54663462.bz2
# Total pages: 8,917,101
# Article pages: 3,754,546
# Redirect pages: 5,162,555
# Total article lenght: 27,304,130,278
# Elapsed time: 2:57:17.77
# 9,000,000
# 9,100,000
# 9,200,000
# File processed: enwiki-20180920-pages-meta-current21.xml-p22722158p23927983.bz2
# Total pages: 9,240,452
# Article pages: 3,873,207
# Redirect pages: 5,367,245
# Total article lenght: 27,998,694,785
# Elapsed time: 3:02:52.56
# 9,300,000
# 9,400,000
# 9,500,000
# 9,600,000
# File processed: enwiki-20180920-pages-meta-current26.xml-p38067203p39567203.bz2
# Total pages: 9,603,508
# Article pages: 4,004,693
# Redirect pages: 5,598,815
# Total article lenght: 28,822,019,304
# Elapsed time: 3:09:31.25
# 9,700,000
# 9,800,000
# 9,900,000
# File processed: enwiki-20180920-pages-meta-current27.xml-p54663462p56163462.bz2
# Total pages: 9,956,231
# Article pages: 4,107,571
# Redirect pages: 5,848,660
# Total article lenght: 29,479,786,702
# Elapsed time: 3:15:39.95
# 10,000,000
# File processed: enwiki-20180920-pages-meta-current24.xml-p33503451p33952815.bz2
# Total pages: 10,051,552
# Article pages: 4,146,927
# Redirect pages: 5,904,625
# Total article lenght: 29,713,996,240
# Elapsed time: 3:17:36.97
# 10,100,000
# 10,200,000
# 10,300,000
# File processed: enwiki-20180920-pages-meta-current24.xml-p30503451p32003451.bz2
# Total pages: 10,386,903
# Article pages: 4,278,842
# Redirect pages: 6,108,061
# Total article lenght: 30,584,419,967
# Elapsed time: 3:24:28.81
# 10,400,000
# 10,500,000
# 10,600,000
# File processed: enwiki-20180920-pages-meta-current27.xml-p47163462p48663462.bz2
# Total pages: 10,684,360
# Article pages: 4,394,264
# Redirect pages: 6,290,096
# Total article lenght: 31,304,053,735
# Elapsed time: 3:30:45.32
# 10,700,000
# 10,800,000
# 10,900,000
# 11,000,000
# File processed: enwiki-20180920-pages-meta-current19.xml-p16120543p17620543.bz2
# Total pages: 11,076,816
# Article pages: 4,506,475
# Redirect pages: 6,570,341
# Total article lenght: 32,017,066,807
# Elapsed time: 3:36:35.83
# 11,100,000
# 11,200,000
# 11,300,000
# 11,400,000
# File processed: enwiki-20180920-pages-meta-current20.xml-p18754736p20254736.bz2
# Total pages: 11,435,146
# Article pages: 4,650,283
# Redirect pages: 6,784,863
# Total article lenght: 32,819,521,560
# Elapsed time: 3:42:50.34
# File processed: enwiki-20180920-pages-meta-current2.xml-p30304p88444.bz2
# Total pages: 11,473,682
# Article pages: 4,677,116
# Redirect pages: 6,796,566
# Total article lenght: 33,519,211,847
# Elapsed time: 3:44:38.96
# 11,500,000
# 11,600,000
# 11,700,000
# 11,800,000
# File processed: enwiki-20180920-pages-meta-current24.xml-p32003451p33503451.bz2
# Total pages: 11,802,509
# Article pages: 4,806,785
# Redirect pages: 6,995,724
# Total article lenght: 34,304,924,104
# Elapsed time: 3:51:23.83
# 11,900,000
# 12,000,000
# 12,100,000
# File processed: enwiki-20180920-pages-meta-current18.xml-p13693074p15193074.bz2
# Total pages: 12,168,162
# Article pages: 4,942,321
# Redirect pages: 7,225,841
# Total article lenght: 35,147,025,429
# Elapsed time: 3:57:35.85
# File processed: enwiki-20180920-pages-meta-current26.xml-p42567203p42663461.bz2
# Total pages: 12,189,266
# Article pages: 4,950,722
# Redirect pages: 7,238,544
# Total article lenght: 35,199,155,508
# Elapsed time: 3:58:01.87
# 12,200,000
# 12,300,000
# 12,400,000
# 12,500,000
# File processed: enwiki-20180920-pages-meta-current27.xml-p50163462p51663462.bz2
# Total pages: 12,530,667
# Article pages: 5,072,566
# Redirect pages: 7,458,101
# Total article lenght: 35,957,004,179
# Elapsed time: 4:05:11.26
# 12,600,000
# 12,700,000
# 12,800,000
# File processed: enwiki-20180920-pages-meta-current14.xml-p6197598p7697598.bz2
# Total pages: 12,883,275
# Article pages: 5,229,978
# Redirect pages: 7,653,297
# Total article lenght: 37,018,564,697
# Elapsed time: 4:11:42.10
# 12,900,000
# 13,000,000
# 13,100,000
# File processed: enwiki-20180920-pages-meta-current27.xml-p44163462p45663462.bz2
# Total pages: 13,168,206
# Article pages: 5,353,225
# Redirect pages: 7,814,981
# Total article lenght: 37,761,511,884
# Elapsed time: 4:18:06.73
# 13,200,000
# 13,300,000
# File processed: enwiki-20180920-pages-meta-current7.xml-p892914p1268691.bz2
# Total pages: 13,336,260
# Article pages: 5,444,018
# Redirect pages: 7,892,242
# Total article lenght: 38,796,840,569
# Elapsed time: 4:21:40.39
# 13,400,000
# 13,500,000
# 13,600,000
# 13,700,000
# File processed: enwiki-20180920-pages-meta-current23.xml-p28323661p29823661.bz2
# Total pages: 13,714,470
# Article pages: 5,566,547
# Redirect pages: 8,147,923
# Total article lenght: 39,468,593,703
# Elapsed time: 4:27:50.04
# 13,800,000
# File processed: enwiki-20180920-pages-meta-current23.xml-p29823661p30503449.bz2
# Total pages: 13,880,616
# Article pages: 5,612,229
# Redirect pages: 8,268,387
# Total article lenght: 39,750,706,149
# Elapsed time: 4:30:39.30
# 13,900,000
# 14,000,000
# 14,100,000
# File processed: enwiki-20180920-pages-meta-current19.xml-p17620543p18754735.bz2
# Total pages: 14,127,867
# Article pages: 5,719,743
# Redirect pages: 8,408,124
# Total article lenght: 40,344,263,531
# Elapsed time: 4:35:26.49
# Total pages: 14,127,867
# Article pages: 5,719,743
# Redirect pages: 8,408,124
# Total article lenght: 40,344,263,531
# Elapsed time: 4:35:26.49
