# %%
import codecs
import csv
import time
import os
import re
import gzip
import pandas as pd
import numpy as np

# %%
PATH_TO_DATA = '/media/andrii/earth/Katia/CS_MasterThesis/data/'
PATH_TO_DATA_EN = PATH_TO_DATA+"enwiki/"
PATH_TO_DATA_UK = PATH_TO_DATA+"ukwiki/"
data_time = '20180920'

# %%
def unpack(file_name):
    file_name_new = file_name.replace(".gz","")
    with gzip.open(file_name, 'rb') as f_in, open(file_name_new, 'wb') as f_out:
        f_out.writelines(f_in)
    return file_name_new

# %%
def pack_and_remove(file_name):
    file_name_new = file_name+'.gz'
    with open(file_name, 'rb') as f_in, gzip.open(file_name_new, 'wb') as f_out:
        f_out.writelines(f_in)
    os.remove(file_name)
    return file_name_new

# %%
UKWIKI_ART_FNMS = []
for file in os.listdir(PATH_TO_DATA):
    if file.endswith("art.csv.gz"):
        UKWIKI_ART_FNMS.append(file)
UKWIKI_RED_FNMS = []
for file in os.listdir(PATH_TO_DATA):
    if file.endswith("red.csv.gz"):
        UKWIKI_RED_FNMS.append(file)

# %%
print('UKWIKI_ART_FNMS:', UKWIKI_ART_FNMS)
print('UKWIKI_RED_FNMS:', UKWIKI_RED_FNMS)
# Out:
# UKWIKI_ART_FNMS: ['enwiki-20180920-pages-meta-current1.xml-p10p30303.bz2_art.csv.gz']
# UKWIKI_RED_FNMS: ['enwiki-20180920-pages-meta-current1.xml-p10p30303.bz2_red.csv.gz']

# %%
df_uk_id_name = None
for fn in UKWIKI_ART_FNMS:
    fn = PATH_TO_DATA+fn
    print(fn)
    fn_new = unpack(fn)
    df_articles = pd.read_csv(fn_new, encoding='UTF-8', quotechar="\"")
    print(df_articles.head(100))
    df_id_name_tmp = df_articles[['id', 'title', 'text_len']].drop_duplicates()
    df_id_name_tmp.columns = ['id', 'title', 'length']
    #print("df_id_name_tmp size: {}".format(df_id_name_tmp.shape))
    if df_uk_id_name is not None:
        df_uk_id_name = df_uk_id_name.append(df_id_name_tmp)        
        #print("append")
    else:
        df_uk_id_name = df_id_name_tmp
        #print("assign")
    print("df_uk_id_name size: {}".format(df_uk_id_name.shape))
    os.remove(fn_new)
df_uk_id_name = df_uk_id_name.drop_duplicates()
# Out:
# /media/andrii/earth/Katia/CS_MasterThesis/BabelNet_baseline/uk-en_redlinks/data/enwiki_20180920/enwiki-20180920-pages-meta-current1.xml-p10p30303.bz2_art.csv.gz
#     id      title  text_len  link_pos  \
# 0   12  Anarchism    193812      2413
# 1   12  Anarchism    193812      3270
# 2   12  Anarchism    193812      3777
# 3   12  Anarchism    193812      6900
# 4   12  Anarchism    193812      6992
# 5   12  Anarchism    193812      7022
# 6   12  Anarchism    193812      7151
# 7   12  Anarchism    193812      7183
# 8   12  Anarchism    193812      8791
# 9   12  Anarchism    193812      8850
# 10  12  Anarchism    193812      8885
# 11  12  Anarchism    193812      9171
# 12  12  Anarchism    193812      9194
# 13  12  Anarchism    193812      9799
# 14  12  Anarchism    193812     10263
# 15  12  Anarchism    193812     10385
# 16  12  Anarchism    193812     11169
# 17  12  Anarchism    193812     11360
# 18  12  Anarchism    193812     11524
# 19  12  Anarchism    193812     11543
# 20  12  Anarchism    193812     11567
# 21  12  Anarchism    193812     12428
# 22  12  Anarchism    193812     21900
# 23  12  Anarchism    193812     21993
# 24  12  Anarchism    193812     22216
# 25  12  Anarchism    193812     22269
# 26  12  Anarchism    193812     22376
# 27  12  Anarchism    193812     22861
# 28  12  Anarchism    193812     23122
# 29  12  Anarchism    193812     23219
# ..  ..        ...       ...       ...
# 70  12  Anarchism    193812     56086
# 71  12  Anarchism    193812     56257
# 72  12  Anarchism    193812     56296
# 73  12  Anarchism    193812     56340
# 74  12  Anarchism    193812     58028
# 75  12  Anarchism    193812     58226
# 76  12  Anarchism    193812     58307
# 77  12  Anarchism    193812     58387
# 78  12  Anarchism    193812     63867
# 79  12  Anarchism    193812     63881
# 80  12  Anarchism    193812     64023
# 81  12  Anarchism    193812     65105
# 82  12  Anarchism    193812     65161
# 83  12  Anarchism    193812     65235
# 84  12  Anarchism    193812     67319
# 85  12  Anarchism    193812     79828
# 86  12  Anarchism    193812     85706
# 87  12  Anarchism    193812     93181
# 88  12  Anarchism    193812     93541
# 89  12  Anarchism    193812     93577
# 90  12  Anarchism    193812     93609
# 91  12  Anarchism    193812     93846
# 92  12  Anarchism    193812     93922
# 93  12  Anarchism    193812     93944
# 94  12  Anarchism    193812     94107
# 95  12  Anarchism    193812     94268
# 96  12  Anarchism    193812     94393
# 97  12  Anarchism    193812     94771
# 98  12  Anarchism    193812     94838
# 99  12  Anarchism    193812     94859
#
#                                              link_val  \
# 0                                      State (polity)
# 1                                  The Globe and Mail
# 2                Routledge Encyclopedia of Philosophy
# 3                        Anarchist schools of thought
# 4                                       individualism
# 5                                        collectivism
# 6                                    Social anarchism
# 7                             individualist anarchism
# 8                                   French Revolution
# 9                              Maximilien Robespierre
# 10                                         Hébertists
# 11                                     William Godwin
# 12                                   Wilhelm Weitling
# 13                                    Joseph Dejacque
# 14                   Anarchist Seeds Beneath the Snow
# 15                                   Dwight Macdonald
# 16                              libertarian anarchism
# 17                                     market economy
# 18                                            Woodcut
# 19                                            Diggers
# 20                           William Everard (Digger)
# 21                                        Zhuang Zhou
# 22                                 Jacobin (politics)
# 23                                           oxymoron
# 24                               Age of Enlightenment
# 25                              Jean-Jacques Rousseau
# 26                                            Encarta
# 27                                    Peter Kropotkin
# 28                                       Edmund Burke
# 29                   A Vindication of Natural Society
# ..                                                ...
# 70                                            Ukraine
# 71                                     Free Territory
# 72                                  Russian Civil War
# 73                                     White movement
# 74                                    Communist party
# 75           General Confederation of Labour (France)
# 76                    Industrial Workers of the World
# 77                                          Comintern
# 78                                              Volin
# 79                                    Sebastien Faure
# 80             International of Anarchist Federations
# 81                                  far-right leagues
# 82                             6 February 1934 crisis
# 83                                       united front
# 84                          Bucknell University Press
# 85                              Solidarity Federation
# 86                                     counterculture
# 87                        anti-globalisation movement
# 88                           World Trade Organization
# 89                                     Group of Eight
# 90                               World Economic Forum
# 91                                         black bloc
# 92                                   security culture
# 93                                     affinity group
# 94  World Trade Organization Ministerial Conferenc...
# 95                                    Simon Critchley
# 96                                     neo-liberalism
# 97               Simon Critchley#Infinitely Demanding
# 98                                    Simon Critchley
# 99                                        Verso Books
#
#                              link_txt
# 0                               state
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                              social
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                                NaN
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                NaN
# 17                     market society
# 18                                NaN
# 19                                NaN
# 20                    William Everard
# 21                           Zhuangzi
# 22                            Jacobin
# 23                                NaN
# 24                      Enlightenment
# 25                                NaN
# 26                                NaN
# 27                                NaN
# 28                                NaN
# 29                                NaN
# ..                                ...
# 70                                NaN
# 71                                NaN
# 72                          civil war
# 73                             Whites
# 74                  communist parties
# 75    General Confederation of Labour
# 76                                NaN
# 77            Communist International
# 78                                NaN
# 79                                NaN
# 80                                NaN
# 81                                NaN
# 82                February 1934 riots
# 83                                NaN
# 84                                NaN
# 85                                NaN
# 86                                NaN
# 87                                NaN
# 88                                NaN
# 89                                NaN
# 90                                NaN
# 91                                NaN
# 92                                NaN
# 93                                NaN
# 94  WTO conference in Seattle in 1999
# 95                                NaN
# 96                                NaN
# 97               Infinitely Demanding
# 98                                NaN
# 99                              Verso
#
# [100 rows x 6 columns]
# df_uk_id_name size: (15041, 3)

# %%
df_uk_id_name.to_csv(PATH_TO_DATA+"ukwiki-" + data_time + "-id_name.csv", 
                     index = False, encoding='UTF-8', quotechar="\"", sep ="^")

# %%
df_uk_id_name = pd.read_csv(PATH_TO_DATA+"ukwiki-" + data_time + "-id_name.csv", encoding='utf-8', sep="^")
df_uk_id_name = df_uk_id_name[['id', 'title']]
df_uk_id_name.head()
# Out:
#     id             title
# 0    3  Головна сторінка
# 1   13         Географія
# 2  584              Атом
# 3  585           Мільярд
# 4  586              Ядро

# %%
df_uk_id_orig_title_alias = pd.read_csv(PATH_TO_DATA+"ukwiki-" + data_time + "-id_orig_title_alias.csv",  encoding='UTF-8', quotechar="\"")
df_uk_id_orig_title_alias.head()
# Out:
#    id_orig           title_alias
# 0      610             Esperanto
# 1     9701             Wikipedia
# 2        3              HomePage
# 3    61817     Капустянко Микола
# 4     6083  Володимир Винниченко

# %%
df_uk_id_orig_title_alias.columns = ['id', 'title']
df_uk_id_name_all = df_uk_id_name.append(df_uk_id_orig_title_alias)
df_uk_id_name_all.shape
# Out:
# (1272761, 2)

# %%
df_uk_id_name_all['title'] = df_uk_id_name_all['title'].str.strip()

# %%
df_uk_id_name_all['title_lc'] = df_uk_id_name_all['title'].str.lower()
df_uk_id_name_all = df_uk_id_name_all[['id', 'title_lc']]
df_uk_id_name_all = df_uk_id_name_all.drop_duplicates()
df_uk_id_name_all.shape
# Out:
# (1264552, 2)

# %%
df_uk_id_name_all.head()
# Out:
#     id          title_lc
# 0    3  головна сторінка
# 1   13         географія
# 2  584              атом
# 3  585           мільярд
# 4  586              ядро

# %%
fn = PATH_TO_DATA+UKWIKI_ART_FNMS[0]
print(fn)
fn_new = unpack(fn)
df_articles = pd.read_csv(fn_new, encoding='UTF-8', quotechar="\"")
df_articles['link_val'] = df_articles['link_val'].str.split("#").str[0] # ???
df_articles = df_articles[df_articles['link_val'].str.strip() != '']
df_articles['link_pos_perc'] = (df_articles['link_pos']/df_articles['text_len']).round(3)    
df_articles['link_val_lc'] = df_articles['link_val'].str.lower()
df_articles.head(100)
# Out:
# /media/andrii/earth/Katia/CS_MasterThesis/BabelNet_baseline/uk-en_redlinks/data/enwiki_20180920/enwiki-20180920-pages-meta-current1.xml-p10p30303.bz2_art.csv.gz
#     id      title  text_len  link_pos  \
# 0   12  Anarchism    193812      2413
# 1   12  Anarchism    193812      3270
# 2   12  Anarchism    193812      3777
# 3   12  Anarchism    193812      6900
# 4   12  Anarchism    193812      6992
# 5   12  Anarchism    193812      7022
# 6   12  Anarchism    193812      7151
# 7   12  Anarchism    193812      7183
# 8   12  Anarchism    193812      8791
# 9   12  Anarchism    193812      8850
# 10  12  Anarchism    193812      8885
# 11  12  Anarchism    193812      9171
# 12  12  Anarchism    193812      9194
# 13  12  Anarchism    193812      9799
# 14  12  Anarchism    193812     10263
# 15  12  Anarchism    193812     10385
# 16  12  Anarchism    193812     11169
# 17  12  Anarchism    193812     11360
# 18  12  Anarchism    193812     11524
# 19  12  Anarchism    193812     11543
# 20  12  Anarchism    193812     11567
# 21  12  Anarchism    193812     12428
# 22  12  Anarchism    193812     21900
# 23  12  Anarchism    193812     21993
# 24  12  Anarchism    193812     22216
# 25  12  Anarchism    193812     22269
# 26  12  Anarchism    193812     22376
# 27  12  Anarchism    193812     22861
# 28  12  Anarchism    193812     23122
# 29  12  Anarchism    193812     23219
# ..  ..        ...       ...       ...
# 70  12  Anarchism    193812     56086
# 71  12  Anarchism    193812     56257
# 72  12  Anarchism    193812     56296
# 73  12  Anarchism    193812     56340
# 74  12  Anarchism    193812     58028
# 75  12  Anarchism    193812     58226
# 76  12  Anarchism    193812     58307
# 77  12  Anarchism    193812     58387
# 78  12  Anarchism    193812     63867
# 79  12  Anarchism    193812     63881
# 80  12  Anarchism    193812     64023
# 81  12  Anarchism    193812     65105
# 82  12  Anarchism    193812     65161
# 83  12  Anarchism    193812     65235
# 84  12  Anarchism    193812     67319
# 85  12  Anarchism    193812     79828
# 86  12  Anarchism    193812     85706
# 87  12  Anarchism    193812     93181
# 88  12  Anarchism    193812     93541
# 89  12  Anarchism    193812     93577
# 90  12  Anarchism    193812     93609
# 91  12  Anarchism    193812     93846
# 92  12  Anarchism    193812     93922
# 93  12  Anarchism    193812     93944
# 94  12  Anarchism    193812     94107
# 95  12  Anarchism    193812     94268
# 96  12  Anarchism    193812     94393
# 97  12  Anarchism    193812     94771
# 98  12  Anarchism    193812     94838
# 99  12  Anarchism    193812     94859
#
#                                              link_val  \
# 0                                      State (polity)
# 1                                  The Globe and Mail
# 2                Routledge Encyclopedia of Philosophy
# 3                        Anarchist schools of thought
# 4                                       individualism
# 5                                        collectivism
# 6                                    Social anarchism
# 7                             individualist anarchism
# 8                                   French Revolution
# 9                              Maximilien Robespierre
# 10                                         Hébertists
# 11                                     William Godwin
# 12                                   Wilhelm Weitling
# 13                                    Joseph Dejacque
# 14                   Anarchist Seeds Beneath the Snow
# 15                                   Dwight Macdonald
# 16                              libertarian anarchism
# 17                                     market economy
# 18                                            Woodcut
# 19                                            Diggers
# 20                           William Everard (Digger)
# 21                                        Zhuang Zhou
# 22                                 Jacobin (politics)
# 23                                           oxymoron
# 24                               Age of Enlightenment
# 25                              Jean-Jacques Rousseau
# 26                                            Encarta
# 27                                    Peter Kropotkin
# 28                                       Edmund Burke
# 29                   A Vindication of Natural Society
# ..                                                ...
# 70                                            Ukraine
# 71                                     Free Territory
# 72                                  Russian Civil War
# 73                                     White movement
# 74                                    Communist party
# 75           General Confederation of Labour (France)
# 76                    Industrial Workers of the World
# 77                                          Comintern
# 78                                              Volin
# 79                                    Sebastien Faure
# 80             International of Anarchist Federations
# 81                                  far-right leagues
# 82                             6 February 1934 crisis
# 83                                       united front
# 84                          Bucknell University Press
# 85                              Solidarity Federation
# 86                                     counterculture
# 87                        anti-globalisation movement
# 88                           World Trade Organization
# 89                                     Group of Eight
# 90                               World Economic Forum
# 91                                         black bloc
# 92                                   security culture
# 93                                     affinity group
# 94  World Trade Organization Ministerial Conferenc...
# 95                                    Simon Critchley
# 96                                     neo-liberalism
# 97                                    Simon Critchley
# 98                                    Simon Critchley
# 99                                        Verso Books
#
#                              link_txt  link_pos_perc  \
# 0                               state          0.012
# 1                                 NaN          0.017
# 2                                 NaN          0.019
# 3                                 NaN          0.036
# 4                                 NaN          0.036
# 5                                 NaN          0.036
# 6                              social          0.037
# 7                                 NaN          0.037
# 8                                 NaN          0.045
# 9                                 NaN          0.046
# 10                                NaN          0.046
# 11                                NaN          0.047
# 12                                NaN          0.047
# 13                                NaN          0.051
# 14                                NaN          0.053
# 15                                NaN          0.054
# 16                                NaN          0.058
# 17                     market society          0.059
# 18                                NaN          0.059
# 19                                NaN          0.060
# 20                    William Everard          0.060
# 21                           Zhuangzi          0.064
# 22                            Jacobin          0.113
# 23                                NaN          0.113
# 24                      Enlightenment          0.115
# 25                                NaN          0.115
# 26                                NaN          0.115
# 27                                NaN          0.118
# 28                                NaN          0.119
# 29                                NaN          0.120
# ..                                ...            ...
# 70                                NaN          0.289
# 71                                NaN          0.290
# 72                          civil war          0.290
# 73                             Whites          0.291
# 74                  communist parties          0.299
# 75    General Confederation of Labour          0.300
# 76                                NaN          0.301
# 77            Communist International          0.301
# 78                                NaN          0.330
# 79                                NaN          0.330
# 80                                NaN          0.330
# 81                                NaN          0.336
# 82                February 1934 riots          0.336
# 83                                NaN          0.337
# 84                                NaN          0.347
# 85                                NaN          0.412
# 86                                NaN          0.442
# 87                                NaN          0.481
# 88                                NaN          0.483
# 89                                NaN          0.483
# 90                                NaN          0.483
# 91                                NaN          0.484
# 92                                NaN          0.485
# 93                                NaN          0.485
# 94  WTO conference in Seattle in 1999          0.486
# 95                                NaN          0.486
# 96                                NaN          0.487
# 97               Infinitely Demanding          0.489
# 98                                NaN          0.489
# 99                              Verso          0.489
#
#                                           link_val_lc
# 0                                      state (polity)
# 1                                  the globe and mail
# 2                routledge encyclopedia of philosophy
# 3                        anarchist schools of thought
# 4                                       individualism
# 5                                        collectivism
# 6                                    social anarchism
# 7                             individualist anarchism
# 8                                   french revolution
# 9                              maximilien robespierre
# 10                                         hébertists
# 11                                     william godwin
# 12                                   wilhelm weitling
# 13                                    joseph dejacque
# 14                   anarchist seeds beneath the snow
# 15                                   dwight macdonald
# 16                              libertarian anarchism
# 17                                     market economy
# 18                                            woodcut
# 19                                            diggers
# 20                           william everard (digger)
# 21                                        zhuang zhou
# 22                                 jacobin (politics)
# 23                                           oxymoron
# 24                               age of enlightenment
# 25                              jean-jacques rousseau
# 26                                            encarta
# 27                                    peter kropotkin
# 28                                       edmund burke
# 29                   a vindication of natural society
# ..                                                ...
# 70                                            ukraine
# 71                                     free territory
# 72                                  russian civil war
# 73                                     white movement
# 74                                    communist party
# 75           general confederation of labour (france)
# 76                    industrial workers of the world
# 77                                          comintern
# 78                                              volin
# 79                                    sebastien faure
# 80             international of anarchist federations
# 81                                  far-right leagues
# 82                             6 february 1934 crisis
# 83                                       united front
# 84                          bucknell university press
# 85                              solidarity federation
# 86                                     counterculture
# 87                        anti-globalisation movement
# 88                           world trade organization
# 89                                     group of eight
# 90                               world economic forum
# 91                                         black bloc
# 92                                   security culture
# 93                                     affinity group
# 94  world trade organization ministerial conferenc...
# 95                                    simon critchley
# 96                                     neo-liberalism
# 97                                    simon critchley
# 98                                    simon critchley
# 99                                        verso books
#
# [100 rows x 8 columns]

# %%
df_articles[df_articles['link_val_lc'] == 'премія «золотий глобус» за найкращий  фільм — драма']
# Out:
#                id             title  text_len  link_pos  \
# 15882153  2101563  Кардинал (фільм)      9436      1489
#
#                                                    link_val  \
# 15882153  Премія «Золотий глобус» за найкращий  фільм — ...
#
#                              link_txt  link_pos_perc  \
# 15882153  найкращий драматичний фільм          0.158
#
#                                                 link_val_lc
# 15882153  премія «золотий глобус» за найкращий  фільм — ...

# %%
df_uk_titles_series = df_articles.iloc[:,7]

# %%
df_uk_titles_series_stripped = df_uk_titles_series.str.replace('  ', ' ')

# %%
df_titles_stripped = df_uk_titles_series_stripped.to_frame()

# %%
#replace not stripped in df_articles with df_titles_stripped
df_articles_less = df_articles[['id', 'title', 'link_val']]

# %%
df_articles = pd.concat([df_articles_less, df_titles_stripped], axis=1)

# %%
df_articles['link_val_lc'] = df_articles['link_val_lc'].str.strip()

# %%
df_articles = pd.merge(df_articles, df_uk_id_name_all, how='left', left_on=['link_val_lc'], right_on=['title_lc'])

# %%
df_articles.head()
# Out:
#    id_x             title            link_val         link_val_lc       id_y  \
# 0     3  Головна сторінка                 NaN                 NaN   190261.0
# 1     3  Головна сторінка                 NaN                 NaN   937102.0
# 2     3  Головна сторінка                 NaN                 NaN  1719596.0
# 3    13         Географія  Об'єкт (філософія)  об'єкт (філософія)   884280.0
# 4    13         Географія           Ератосфен           ератосфен    21623.0
#
#              title_lc
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3  об'єкт (філософія)
# 4           ератосфен

# %%
df_articles = df_articles[['id_x', 'id_y', 'link_val']]
df_articles.columns = ['id', 'link_id', 'link_val']
df_articles.head()
# Out:
#    id    link_id            link_val
# 0   3   190261.0                 NaN
# 1   3   937102.0                 NaN
# 2   3  1719596.0                 NaN
# 3  13   884280.0  Об'єкт (філософія)
# 4  13    21623.0           Ератосфен

# %%
df_articles = df_articles[pd.notnull(df_articles['link_val'])]

# %%
df_articles[['link_id']] = df_articles[['link_id']].fillna(-1).astype(int)
df_articles['is_red_link'] = np.where(df_articles['link_id'] == -1, True, False)

# %%
df_articles.to_csv('ukwiki-20180920-pages-links.csv.gz', index = False, encoding='UTF-8', quotechar="\"")

# %%
pack_and_remove(fn_new)

# %%
# !pwd
# Out:
# /media/andrii/earth/Katia/BabelNet_baseline/uk-en_redlinks/code/get_redlinks_from_dumps

# %%
df_id_name = pd.read_csv(PATH_TO_DATA+'enwiki-' + data_time + '-id_name.csv', encoding='ISO-8859-1', quotechar="'", escapechar ="\\")

# %%
df_id_name.head()
# Out:
#     id      title
# 0   12  Anarchism
# 1   25     Autism
# 2   39     Albedo
# 3  290          A
# 4  303    Alabama

# %%
fn = PATH_TO_DATA+"ukwiki-" + data_time + "-langlinks_en.csv"
df_en_langlinks = pd.read_csv(fn, encoding='UTF-16', sep="^")

# %%
df_en_langlinks = df_en_langlinks[pd.notnull(df_en_langlinks['ll_title'])]

# %%
df_en_langlinks.head()
# Out:
#     ll_from ll_lang                          ll_title
# 23  2112530      en  ! (The Dismemberment Plan album)
# 24  1366003      en                ! (disambiguation)
# 25  2141483      en                                !!
# 26   425480      en                               !!!
# 27   848226      en                     !Action Pact!

# %%
#df_uk_en_links = pd.merge(df_en_langlinks, df_id_name, how='left', left_on=['ll_title'], right_on=['title'])

# %%
df_uk_en_links = df_uk_en_links[['ll_from', 'id']]
df_uk_en_links.columns = ['id_uk', 'id_en']
df_uk_en_links[['id_uk']] = df_uk_en_links[['id_uk']].fillna(-1).astype(int)
df_uk_en_links[['id_en']] = df_uk_en_links[['id_en']].fillna(-1).astype(int)
df_uk_en_links.to_csv(PATH_TO_DATA_UK + data_time + "-langlinks_uk_en.csv", index = False, 
                      encoding='ISO-8859-1', quotechar="'", 
                      escapechar ="\\", quoting=csv.QUOTE_NONNUMERIC)
pack_and_remove(fn_new)

# %%
df_en_langlinks.to_csv(PATH_TO_DATA + data_time + "-langlinks_uk_en.csv", index = False, 
                      encoding='ISO-8859-1', quotechar="'", 
                      escapechar ="\\", quoting=csv.QUOTE_NONNUMERIC)
