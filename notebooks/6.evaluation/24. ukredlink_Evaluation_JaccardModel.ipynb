# %%
import pandas as pd

# %%
import sys
sys.path.insert(0, '/media/andrii/earth/Katia/CS_MasterThesis/Red_links_Project_for_Wiki_draft/py')
import functions

# %%
PATH_TO_DATA = '/media/andrii/earth/Katia/CS_MasterThesis/data/ukwiki/uk_red_links/'

# %%
bn_results_df = pd.read_csv(PATH_TO_DATA+'uk_red_links_results_lighter.csv')

# %%
bn_results_df
# Out:
#                                           red_link_name  \
# 0                                           Каунт Бейсі
# 1                                              аль-Каїм
# 2                                              королева
# 3                                         Prentice Hall
# 4                                              Tokar.ua
# 5     Monthly Notices of the Royal Astronomical Society
# 6                                    Світ (видавництво)
# 7                               Дубович Іван Андрійович
# 8                                помірні повітряні маси
# 9                          Доповідь про торгівлю людьми
# 10    Управління з моніторингу та боротьби з торгівл...
# 11    Управління з моніторингу та боротьби з торгівл...
# 12                          Руденко Ірина Станіславівна
# 13                         Радченко Вероніка Вікторівна
# 14                        Вакуленко Олена Володимирівна
# 15                          Скуратович Олег Ярославович
# 16                                Чанцева Ніна Іванівна
# 17      Головне управління геодезії та картографії СРСР
# 18                                         Random House
# 19                                     Simon & Schuster
# 20                                    Панчакутек Юпанкі
# 21                                                Земун
# 22                            Східний тюркський каганат
# 23                                  Приморська Хорватія
# 24                                           Раштакурти
# 25                                           моніторинг
# 26                        Купрієнко Сергій Анатолійович
# 27                             Талах Віктор Миколайович
# 28                                             Керкраде
# 29                                 Daylight saving time
# ...                                                 ...
# 3164                                Ніколе Мунс-Ягерман
# 3165                                       Андреа Леанд
# 3166                                      Беверлі Бовіс
# 3167                         Сенді Коллінз (тенісистка)
# 3168                            Луїс Аллен (тенісистка)
# 3169                                        Лаура Аррая
# 3170                                       С'юзен Слоун
# 3171                                   Пінат Луї Гарпер
# 3172                                       Пілар Васкес
# 3173                                              Ху На
# 3174                                       Кім Стейнмец
# 3175                                         Пем Кеселі
# 3176                                        Ліса Бондер
# 3177                                        Іноуе Ецуко
# 3178                                         Ева Крапль
# 3179                                      Сабрина Голеш
# 3180                                        Террі Фелпс
# 3181                                         Селін Коен
# 3182                            Венді Вайт (тенісистка)
# 3183                                     Тіна Мочідзукі
# 3184                                         Нейже Діас
# 3185                                       Карен Шимпер
# 3186                                      Мішелл Торрес
# 3187                                      Лі Антонопліс
# 3188                                     Мері-Лу П'ятек
# 3189                                   Патрісія Медрадо
# 3190                                    С'юзен Маскарін
# 3191                                      Алісія Молтон
# 3192                                    Сабіна Сіммондс
# 3193                                         Latin Rite
#
#                                              en_similar  \
# 0     [(0.081, 'The Count Basie Story'), (0.076, 'Th...
# 1     [(0.031, 'Ahmad al-Muqtadir'), (0.03, 'Cai Xia...
# 2     [(0.033, 'List of consorts of the monarch of I...
# 3     [(0.078, 'Chemical tanker'), (0.067, 'Break of...
# 4     [(0.05, 'List of virtual communities with more...
# 5     [(0.035, 'Local group'), (0.034, 'Astrophysics...
# 6     [(0.058, 'Our World In Data'), (0.044, 'Break ...
# 7     [(0.061, 'Our World In Data'), (0.046, 'Break ...
# 8     [(0.037, 'Color term'), (0.035, 'Gennady Nevel...
# 9     [(0.134, 'Our World In Data'), (0.06, 'Ageing ...
# 10    [(0.134, 'Our World In Data'), (0.06, 'Ageing ...
# 11    [(0.123, 'Our World In Data'), (0.055, 'Ageing...
# 12    [(0.053, 'Our World In Data'), (0.042, 'Break ...
# 13    [(0.053, 'Our World In Data'), (0.042, 'Break ...
# 14    [(0.053, 'Our World In Data'), (0.042, 'Break ...
# 15    [(0.056, 'Our World In Data'), (0.043, 'Break ...
# 16    [(0.061, 'Our World In Data'), (0.045, 'Break ...
# 17    [(0.109, 'Our World In Data'), (0.049, 'Ageing...
# 18    [(0.035, 'Queen Rocks'), (0.035, 'Agora SA'), ...
# 19    [(0.038, 'The Years of Rice and Salt'), (0.037...
# 20    [(0.036, 'Zhu Quan'), (0.036, 'Liverpool Castl...
# 21    [(0.036, 'Hannes Trautloft'), (0.033, 'Nova Cr...
# 22    [(0.063, 'Shahin Vahmanzadegan'), (0.057, 'Mel...
# 23    [(0.083, 'Seisyllwg'), (0.08, 'Anarawd ap Rhod...
# 24    [(0.241, 'Ten Kingdoms'), (0.063, 'Bruno the G...
# 25    [(0.02, 'Seismic hazard'), (0.014, 'SoftLayer'...
# 26    [(0.06, 'Inca Civil War'), (0.046, 'INTI Inter...
# 27    [(0.086, 'Inca Civil War'), (0.063, 'Classic M...
# 28    [(0.048, 'Yannis Anastasiou'), (0.047, 'Robert...
# 29    [(0.23, 'Treemapping'), (0.075, 'White Hispani...
# ...                                                 ...
# 3164  [(0.172, 'Nicole Muns-Jagerman'), (0.132, 'Sil...
# 3165  [(0.235, 'Andrea Leand'), (0.125, 'Leigh-Anne ...
# 3166  [(0.343, 'Beverly Bowes'), (0.161, 'Michelle T...
# 3167  [(0.118, 'Dana Gilbert'), (0.101, 'Sandy Colli...
# 3168  [(0.312, 'Louise Allen (tennis)'), (0.167, 'Ca...
# 3169  [(0.176, 'Jenny Klitch'), (0.151, 'Laura Array...
# 3170  [(0.484, 'Susan Sloane'), (0.161, 'Halle Cioff...
# 3171  [(0.173, 'Susan Sloane'), (0.155, 'Peanut Loui...
# 3172  [(0.145, 'Shelley Solomon'), (0.142, 'Vicki Ne...
# 3173  [(0.318, 'Hu Na'), (0.2, 'Karen Schimper'), (0...
# 3174  [(0.245, 'Kim Steinmetz'), (0.139, 'Jenny Klit...
# 3175  [(0.281, 'Pam Casale'), (0.184, 'Jenny Klitch'...
# 3176  [(0.279, 'Lisa Bonder'), (0.154, 'Jenny Klitch...
# 3177  [(0.325, 'Etsuko Inoue'), (0.182, 'Tina Mochiz...
# 3178  [(0.317, 'Eva Krapl'), (0.167, 'Stacey Martin'...
# 3179  [(0.208, 'Laura Lapi'), (0.202, 'Federica Bons...
# 3180  [(0.314, 'Terry Phelps'), (0.189, 'Michelle To...
# 3181  [(0.203, 'Laura Lapi'), (0.159, 'Luciana Corsa...
# 3182  [(0.239, 'Wendy White (tennis)'), (0.128, 'Ter...
# 3183  [(0.394, 'Tina Mochizuki'), (0.135, 'Debbie Sp...
# 3184  [(0.297, 'Niege Dias'), (0.164, 'Laura Lapi'),...
# 3185  [(0.418, 'Karen Schimper'), (0.177, 'Elly Haka...
# 3186  [(0.418, 'Michelle Torres'), (0.161, 'Karen Sc...
# 3187  [(0.163, 'Lea Antonoplis'), (0.133, 'Vicki Nel...
# 3188  [(0.153, 'Michelle Torres'), (0.141, 'Mary-Lou...
# 3189  [(0.182, 'Patricia Medrado'), (0.156, 'Dana Gi...
# 3190  [(0.271, 'Susan Mascarin'), (0.191, 'Vicki Nel...
# 3191  [(0.174, 'Alycia Moulton'), (0.145, 'Leigh-Ann...
# 3192  [(0.255, 'Sabina Simmonds'), (0.196, 'Leigh-An...
# 3193  [(0.066, 'List of Catholic dioceses in Spain, ...
#
#                                            ground_truth Evaluation  \
# 0                                           Count Basie         FP
# 1     ?? Al-Qa'im (town), Al-Qa'im (Cairo), Al-Qa'im...         FP
# 2     ?? gyne, monarch, queen_regnant, queen_(chess)...         FP
# 3                                         Prentice Hall         FP
# 4                                                   NaN         FP
# 5     Monthly_Notices_of_the_Royal_Astronomical_Society         FP
# 6                                                   NaN         FP
# 7                                                   NaN         FP
# 8                                                   NaN         FP
# 9                         Trafficking in Persons Report         FP
# 10                                                  NaN         FP
# 11    Office to Monitor and Combat Trafficking in Pe...         FP
# 12                                                  NaN         FP
# 13                                                  NaN         FP
# 14                                                  NaN         FP
# 15                                                  NaN         FP
# 16                                                  NaN         FP
# 17                                                  NaN         FP
# 18                                         Random_House         FP
# 19                                     Simon & Schuster         FP
# 20                                            Pachacuti         FP
# 21                                   ?? FK_Zemun, Zemun         FP
# 22                                                  NaN         FP
# 23                                     Duchy_of_Croatia         FP
# 24                                                  NaN         FP
# 25                               'monitoring_(medicine)         FP
# 26                                                  NaN         FP
# 27                                                  NaN         FP
# 28                                             Kerkrade         FP
# 29                                 Daylight saving time         FP
# ...                                                 ...        ...
# 3164                               Nicole Muns-Jagerman         TP
# 3165                                       Andrea Leand         TP
# 3166                                      Beverly Bowes         TP
# 3167                             Sandy Collins (tennis)         FP
# 3168                              Louise Allen (tennis)         TP
# 3169                                       Laura Arraya         FP
# 3170                                       Susan Sloane         TP
# 3171                                Peanut Louie Harper         FP
# 3172                                      Pilar Vásquez         FP
# 3173                                              Hu Na         TP
# 3174                                      Kim Steinmetz         TP
# 3175                                         Pam Casale         TP
# 3176                                        Lisa Bonder         TP
# 3177                                       Etsuko Inoue         TP
# 3178                                          Eva Krapl         TP
# 3179                                      Sabrina Goleš         FP
# 3180                                       Terry Phelps         TP
# 3181                                       Céline Cohen         FP
# 3182                               Wendy White (tennis)         TP
# 3183                                     Tina Mochizuki         TP
# 3184                                         Niege Dias         TP
# 3185                                     Karen Schimper         TP
# 3186                                    Michelle Torres         TP
# 3187                                     Lea Antonoplis         TP
# 3188                                   Mary-Lou Daniels         FP
# 3189                                   Patricia Medrado         TP
# 3190                                     Susan Mascarin         TP
# 3191                                     Alycia Moulton         TP
# 3192                                    Sabina Simmonds         TP
# 3193                                         Roman Rite         FP
#
#                              Remarks Proper Name  Person  Latin
# 0                                NaN          PN  Person    NaN
# 1                                NaN          PN     NaN    NaN
# 2                                NaN         NaN     NaN    NaN
# 3                                NaN          PN     NaN  Latin
# 4                                NaN          PN     NaN  Latin
# 5     Right item present in the list          PN     NaN  Latin
# 6                                NaN          PN     NaN    NaN
# 7                                NaN          PN  Person    NaN
# 8                                NaN         NaN     NaN    NaN
# 9                                NaN          PN     NaN    NaN
# 10                               NaN          PN     NaN    NaN
# 11                               NaN          PN     NaN    NaN
# 12                               NaN          PN  Person    NaN
# 13                               NaN          PN  Person    NaN
# 14                               NaN          PN  Person    NaN
# 15                               NaN          PN  Person    NaN
# 16                               NaN          PN  Person    NaN
# 17                               NaN          PN     NaN    NaN
# 18                               NaN          PN     NaN  Latin
# 19                               NaN          PN     NaN  Latin
# 20                               NaN          PN  Person    NaN
# 21    Right item present in the list          PN     NaN    NaN
# 22                               NaN          PN     NaN    NaN
# 23                               NaN          PN     NaN    NaN
# 24                               NaN          PN     NaN    NaN
# 25                               NaN         NaN     NaN    NaN
# 26                               NaN          PN  Person    NaN
# 27                               NaN          PN  Person    NaN
# 28    Right item present in the list          PN     NaN    NaN
# 29                               NaN         NaN     NaN  Latin
# ...                              ...         ...     ...    ...
# 3164                             NaN          PN  Person    NaN
# 3165                             NaN          PN  Person    NaN
# 3166                             NaN          PN  Person    NaN
# 3167  Right item present in the list          PN  Person    NaN
# 3168                             NaN          PN  Person    NaN
# 3169  Right item present in the list          PN  Person    NaN
# 3170                             NaN          PN  Person    NaN
# 3171  Right item present in the list          PN  Person    NaN
# 3172                             NaN          PN  Person    NaN
# 3173                             NaN          PN  Person    NaN
# 3174                             NaN          PN  Person    NaN
# 3175                             NaN          PN  Person    NaN
# 3176                             NaN          PN  Person    NaN
# 3177                             NaN          PN  Person    NaN
# 3178                             NaN          PN  Person    NaN
# 3179                             NaN          PN  Person    NaN
# 3180                             NaN          PN  Person    NaN
# 3181                             NaN          PN  Person    NaN
# 3182                             NaN          PN  Person    NaN
# 3183                             NaN          PN  Person    NaN
# 3184                             NaN          PN  Person    NaN
# 3185                             NaN          PN  Person    NaN
# 3186                             NaN          PN  Person    NaN
# 3187                             NaN          PN  Person    NaN
# 3188  Right item present in the list          PN  Person    NaN
# 3189                             NaN          PN  Person    NaN
# 3190                             NaN          PN  Person    NaN
# 3191                             NaN          PN  Person    NaN
# 3192                             NaN          PN  Person    NaN
# 3193                             NaN         NaN     NaN  Latin
#
# [3194 rows x 8 columns]

# %%
functions.f1_score(bn_results_df['Evaluation'])
# Out:
# precision = 0.32588864422774455
# recall = 0.9971126082771896
# f1_score = 0.49122807017543857
# (0.32588864422774455, 0.9971126082771896, 0.49122807017543857)

# %%
false_negatives_df = bn_results_df.loc[bn_results_df['Evaluation'] == 'FN']

# %%
false_negatives_df.to_csv('false_negatives_df.csv', encoding='UTF-8')

# %%
false_positives_df = bn_results_df.loc[bn_results_df['Evaluation'] == 'FP']

# %%
false_positives_df.to_csv('false_positives_df.csv', encoding='UTF-8')
