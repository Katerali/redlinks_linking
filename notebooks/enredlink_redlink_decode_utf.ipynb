# %%
import pandas as pd

# %%
PATH_TO_DATA = '/media/andrii/earth/Katia/CS_MasterThesis/Red_links_Project_for_Wiki/results'

# %%
df_red_links3593 = pd.read_csv(PATH_TO_DATA+'bn_results_all_final.csv', encoding = 'UTF-16')

# %%
df_red_links3593
# Out:
#                                           red_link_name
# 0                                              Cleonini
# 1                              West Coast Mafia Records
# 2                                             Killa Tay
# 3                           Denver Film Critics Society
# 4                                              Wim Smet
# 5                                      RadosÅaw Glonek
# 6                                         Sten Priinits
# 7                                       Richard HÃ¼bers
# 8                                       Nicolas Rousset
# 9                                    Kateryna Chentsova
# 10                                 Anastasiya Moskovska
# 11                                           Anne Sauer
# 12                                         Maria Boldor
# 13                                         Giulia Rizzi
# 14                                      Sevil Bunyatova
# 15                                        Sibylle Klemm
# ...

# %%
f = lambda x: x.encode('latin1')
df_red_links3593 = df_red_links3593.applymap(f)

# %%
f_decode = lambda x: x.decode('utf8')
df_red_links3593 = df_red_links3593.applymap(f_decode)

# %%
df_red_links3593
# Out:
#                                           red_link_name
# 0                                              Cleonini
# 1                              West Coast Mafia Records
# 2                                             Killa Tay
# 3                           Denver Film Critics Society
# 4                                              Wim Smet
# 5                                       Radosław Glonek
# 6                                         Sten Priinits
# 7                                        Richard Hübers
# 8                                       Nicolas Rousset
# 9                                    Kateryna Chentsova
# 10                                 Anastasiya Moskovska
# 11                                           Anne Sauer
# 12                                         Maria Boldor
# 13                                         Giulia Rizzi
# 14                                      Sevil Bunyatova
# 15                                        Sibylle Klemm
# ...

# %%
red_links3593_list = df_red_links3593['red_link_name'].tolist()

# %%
df_red_links3593.to_csv('red_links_3593_dec.csv', header=False, index=False)
