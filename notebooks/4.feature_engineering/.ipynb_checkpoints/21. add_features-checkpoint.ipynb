# %%
import pandas as pd

import numpy as np
from numpy import nan as Nan

import math

import transliterate
from transliterate import translit, get_available_language_codes

# %%
import sys
sys.path.insert(0, '/media/andrii/earth/Katia/CS_MasterThesis/Red_links_Project_for_Wiki_draft/py')
import functions

# %%
def extract_list(s):
    return [x.split(',')[1].strip("', ,\"") for x in s[2:-2].split('), (')]

def extract_score(s):
    return [float(x.split(',')[0].strip("', ,\"")) for x in s[2:-2].split('), (')]

def levenshteinDistance(s1, s2):
    if len(s1) > len(s2):
        s1, s2 = s2, s1

    distances = range(len(s1) + 1)
    for i2, c2 in enumerate(s2):
        distances_ = [i2+1]
        for i1, c1 in enumerate(s1):
            if c1 == c2:
                distances_.append(distances[i1])
            else:
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
        distances = distances_
    return distances[-1]

# %%
PATH_TO_DATA = '/media/andrii/earth/Katia/CS_MasterThesis/data/'
PATH_TO_DATA_RL = '/media/andrii/earth/Katia/CS_MasterThesis/data/ukwiki/uk_red_links/'
PATH_TO_DATA_UK = '/media/andrii/earth/Katia/CS_MasterThesis/data/ukwiki/ukwiki_20180920/'
PATH_TO_DATA_EN = '/media/andrii/earth/Katia/CS_MasterThesis/data/ukwiki/enwiki_20180920/'

# %%
# read a train sample
train_sample = pd.read_csv(PATH_TO_DATA_RL+'train_red_links_uk.csv', encoding = 'UTF-8')

# %%
train_list = train_sample['red_link_name'].tolist()

# %%
candidates = pd.read_csv(PATH_TO_DATA_RL+'uk_red_links_results_all_candidates.csv', encoding = 'UTF-8')

# %%
train_candidates = pd.merge(train_sample, candidates, how='inner', left_on='red_link_name', right_on='red_link_name')

# %%
train_candidates.head()
# Out:
#                                        red_link_name  \
# 0                                        Каунт Бейсі
# 1                                           аль-Каїм
# 2                                           королева
# 3                                      Prentice Hall
# 4  Monthly Notices of the Royal Astronomical Society
#
#                                           en_similar
# 0  [(0.081, 'The Count Basie Story'), (0.076, 'Th...
# 1  [(0.031, 'Ahmad al-Muqtadir'), (0.03, 'Cai Xia...
# 2  [(0.033, 'List of consorts of the monarch of I...
# 3  [(0.078, 'Chemical tanker'), (0.067, 'Break of...
# 4  [(0.035, 'Local group'), (0.034, 'Astrophysics...

# %%
[train_candidates['red_link_name'][0]]
# Out:
# ['Каунт Бейсі']

# %%
all_results = {}
all_results_list = [[]] * train_candidates.shape[0]
for i in range(train_candidates.shape[0]):
    if train_candidates['en_similar'][i] == '[]':
        all_results[train_candidates['red_link_name'][i]] = []
        all_results_list[i] = []
    else:
        res = extract_list(train_candidates['en_similar'][i])
        all_results[train_candidates['red_link_name'][i]] = res
        all_results_list[i] = res

# %%
len(all_results.keys())
# Out:
# 2518

# %%
df = pd.DataFrame.from_dict(all_results, orient = 'index')

# %%
rl_with_cand = df.stack().reset_index(level=1, drop=True).to_frame(name='candidate')

# %%
rl_with_cand['red_link_name'] = rl_with_cand.index

# %%
rl_with_cand
# Out:
#                                                candidate    red_link_name
# Каунт Бейсі                        The Count Basie Story      Каунт Бейсі
# Сабіна Сіммондс                 Alexia Dechaume-Balleret  Сабіна Сіммондс
# Сабіна Сіммондс                          Marianne Werdel  Сабіна Сіммондс
# Сабіна Сіммондс                              Jenny Byrne  Сабіна Сіммондс
# Сабіна Сіммондс                           Claudia Porwik  Сабіна Сіммондс
# Сабіна Сіммондс                           Barbara Paulus  Сабіна Сіммондс
# Сабіна Сіммондс                     Robin White (tennis)  Сабіна Сіммондс
# Сабіна Сіммондс                              Lori McNeil  Сабіна Сіммондс
# Сабіна Сіммондс                         Katerina Maleeva  Сабіна Сіммондс
# Сабіна Сіммондс                           Judith Wiesner  Сабіна Сіммондс
# Сабіна Сіммондс                             Elna Reinach  Сабіна Сіммондс
# Сабіна Сіммондс                     UPI (disambiguation)  Сабіна Сіммондс
# Сабіна Сіммондс                         Nathalie Tauziat  Сабіна Сіммондс
# Сабіна Сіммондс                             Mercedes Paz  Сабіна Сіммондс
# Сабіна Сіммондс                 University of California  Сабіна Сіммондс
#
# [2338569 rows x 2 columns]

# %%
# add BabelNet results
BN_results = pd.read_csv(PATH_TO_DATA_RL+'BN_ukredlinks_wiki_evaluated.csv', encoding = 'UTF-8')

# %%
BN_results.head()
# Out:
#    red link name                                              EN BN  \
# 0    Каунт Бейсі                                                NaN
# 1       аль-Каїм                                  Al-Qa'im (caliph)
# 2       королева  gyne, monarch, queen regnant, queen (chess), T...
# 3  Prentice Hall                                                NaN
# 4       Tokar.ua                                                NaN
#
#                                EN if else Evaluation  \
# 0                             Count Basie         FN
# 1  also Al-Qa'im (town), Al-Qa'im (Cairo)         FP
# 2                                     NaN         FP
# 3                           Prentice Hall         FN
# 4                                     NaN         TN
#
#                                              Remarks
# 0                                                NaN
# 1  article in UK Wiki exists. Impossible to know ...
# 2                   right item not first in the list
# 3                                                NaN
# 4                                                NaN

# %%
df_with_BN = pd.merge(rl_with_cand, BN_results, how='left', left_on='red_link_name', right_on='red link name')

# %%
df_with_BN.shape
# Out:
# (2338569, 7)

# %%
df_with_BN = df_with_BN[['red_link_name','candidate', 'EN BN']]

# %%
df_with_BN
# Out:
#            red_link_name                                candidate EN BN
# 0            Каунт Бейсі                    The Count Basie Story   NaN
# 1            Каунт Бейсі                     The Atomic Mr. Basie   NaN
# 2            Каунт Бейсі                          Basie in London   NaN
# 3            Каунт Бейсі                               Basie Jazz   NaN
# 4            Каунт Бейсі                            Basie (album)   NaN
# 5            Каунт Бейсі        Everyday I Have the Blues (album)   NaN
# 6            Каунт Бейсі                               The Count!   NaN
# 7            Каунт Бейсі          Golden Boy (Quincy Jones album)   NaN
# 8            Каунт Бейсі                Dance Session Album No. 2   NaN
# 9            Каунт Бейсі                   Count Basie at Newport   NaN
# 10           Каунт Бейсі                 One O'Clock Jump (album)   NaN
# 11           Каунт Бейсі                          I/We Had a Ball   NaN
# 12           Каунт Бейсі                        Kansas City Suite   NaN
# 13           Каунт Бейсі         Hall of Fame (Count Basie album)   NaN
# 14           Каунт Бейсі                      Basie One More Time   NaN
# 15           Каунт Бейсі                      This Time by Basie!   NaN
# 16           Каунт Бейсі              On My Way & Shoutin' Again!   NaN
# 17           Каунт Бейсі                            Dance Session   NaN
# 18           Каунт Бейсі                   Dance Along with Basie   NaN
# 19           Каунт Бейсі             Breakfast Dance and Barbecue   NaN
# 20           Каунт Бейсі                            I Dig Dancers   NaN
# 21           Каунт Бейсі  Hoochie Coochie Man (Jimmy Smith album)   NaN
# 22           Каунт Бейсі                          Ella and Basie!   NaN
# 23           Каунт Бейсі                    Sing Along with Basie   NaN
# 24           Каунт Бейсі         The Greatest!! Count Basie Plays   NaN
# 25           Каунт Бейсі                          Back with Basie   NaN
# 26           Каунт Бейсі                   April in Paris (album)   NaN
# 27           Каунт Бейсі                       Count Basie Swings   NaN
# 28           Каунт Бейсі                 Metronome All-Stars 1956   NaN
# 29           Каунт Бейсі                 Jazz at the Philharmonic   NaN
# ...                  ...                                      ...   ...
# 2338539  Сабіна Сіммондс                       Isabelle Demongeot   NaN
# 2338540  Сабіна Сіммондс                                    Hu Na   NaN
# 2338541  Сабіна Сіммондс                     Svetlana Parkhomenko   NaN
# 2338542  Сабіна Сіммондс                           Stephanie Rehe   NaN
# 2338543  Сабіна Сіммондс                      Patricia Hy-Boulais   NaN
# 2338544  Сабіна Сіммондс                          Janine Thompson   NaN
# 2338545  Сабіна Сіммондс                         Belinda Cordwell   NaN
# 2338546  Сабіна Сіммондс                      Tine Scheuer-Larsen   NaN
# 2338547  Сабіна Сіммондс                              Silke Meier   NaN
# 2338548  Сабіна Сіммондс                        Philip Morris USA   NaN
# 2338549  Сабіна Сіммондс                             Louise Field   NaN
# 2338550  Сабіна Сіммондс                     Lesley Turner Bowrey   NaN
# 2338551  Сабіна Сіммондс                             Helen Kelesi   NaN
# 2338552  Сабіна Сіммондс                          Heather Ludloff   NaN
# 2338553  Сабіна Сіммондс                 Glossary of tennis terms   NaN
# 2338554  Сабіна Сіммондс                            Bettina Fulco   NaN
# 2338555  Сабіна Сіммондс                 Alexia Dechaume-Balleret   NaN
# 2338556  Сабіна Сіммондс                          Marianne Werdel   NaN
# 2338557  Сабіна Сіммондс                              Jenny Byrne   NaN
# 2338558  Сабіна Сіммондс                           Claudia Porwik   NaN
# 2338559  Сабіна Сіммондс                           Barbara Paulus   NaN
# 2338560  Сабіна Сіммондс                     Robin White (tennis)   NaN
# 2338561  Сабіна Сіммондс                              Lori McNeil   NaN
# 2338562  Сабіна Сіммондс                         Katerina Maleeva   NaN
# 2338563  Сабіна Сіммондс                           Judith Wiesner   NaN
# 2338564  Сабіна Сіммондс                             Elna Reinach   NaN
# 2338565  Сабіна Сіммондс                     UPI (disambiguation)   NaN
# 2338566  Сабіна Сіммондс                         Nathalie Tauziat   NaN
# 2338567  Сабіна Сіммондс                             Mercedes Paz   NaN
# 2338568  Сабіна Сіммондс                 University of California   NaN
#
# [2338569 rows x 3 columns]

# %%
# strip all string values in a dataframe

df_with_BN_obj = df_with_BN.select_dtypes(['object'])
df_with_BN[df_with_BN_obj.columns] = df_with_BN_obj.apply(lambda x: x.str.strip())

# %%
df_with_BN
# Out:
#            red_link_name                                candidate EN BN
# 2338558  Сабіна Сіммондс                           Claudia Porwik   NaN
# 2338559  Сабіна Сіммондс                           Barbara Paulus   NaN
# 2338560  Сабіна Сіммондс                     Robin White (tennis)   NaN
# 2338561  Сабіна Сіммондс                              Lori McNeil   NaN
# 2338562  Сабіна Сіммондс                         Katerina Maleeva   NaN
# 2338563  Сабіна Сіммондс                           Judith Wiesner   NaN
# 2338564  Сабіна Сіммондс                             Elna Reinach   NaN
# 2338565  Сабіна Сіммондс                     UPI (disambiguation)   NaN
# 2338566  Сабіна Сіммондс                         Nathalie Tauziat   NaN
# 2338567  Сабіна Сіммондс                             Mercedes Paz   NaN
# 2338568  Сабіна Сіммондс                 University of California   NaN
#
# [2338569 rows x 3 columns]

# %%
bn_results = []
for index, row in df_with_BN.iterrows():
    bn_result = row['candidate'] == row['EN BN']
    bn_results.append(bn_result)

# %%
BN_df = pd.DataFrame(bn_results)

# %%
with_BN_df = pd.concat([df_with_BN, BN_df], axis=1)
with_BN_df.columns = ['red_link_name', 'candidate', 'EN BN', 'BN_results']
with_BN_df = with_BN_df[['red_link_name', 'candidate', 'BN_results']]

# %%
with_BN_df.head()
# Out:
#   red_link_name              candidate BN_results
# 0   Каунт Бейсі  The Count Basie Story      False
# 1   Каунт Бейсі   The Atomic Mr. Basie      False
# 2   Каунт Бейсі        Basie in London      False
# 3   Каунт Бейсі             Basie Jazz      False
# 4   Каунт Бейсі          Basie (album)      False

# %%
with_BN_df['BN_results'] = with_BN_df['BN_results'].replace({False: '0'})

# %%
with_BN_df['BN_results'] = with_BN_df['BN_results'].replace({True: '1'})

# %%
with_BN_df
# Out:
#            red_link_name                                candidate BN_results
# 0            Каунт Бейсі                    The Count Basie Story          0
# 1            Каунт Бейсі                     The Atomic Mr. Basie          0
# 2            Каунт Бейсі                          Basie in London          0
# 3            Каунт Бейсі                               Basie Jazz          0
# 4            Каунт Бейсі                            Basie (album)          0
# 5            Каунт Бейсі        Everyday I Have the Blues (album)          0
# 6            Каунт Бейсі                               The Count!          0
# 7            Каунт Бейсі          Golden Boy (Quincy Jones album)          0
# 8            Каунт Бейсі                Dance Session Album No. 2          0
# 9            Каунт Бейсі                   Count Basie at Newport          0
# 10           Каунт Бейсі                 One O'Clock Jump (album)          0
# 11           Каунт Бейсі                          I/We Had a Ball          0
# 12           Каунт Бейсі                        Kansas City Suite          0
# 13           Каунт Бейсі         Hall of Fame (Count Basie album)          0
# 14           Каунт Бейсі                      Basie One More Time          0
# 15           Каунт Бейсі                      This Time by Basie!          0
# 16           Каунт Бейсі              On My Way & Shoutin' Again!          0
# 17           Каунт Бейсі                            Dance Session          0
# 18           Каунт Бейсі                   Dance Along with Basie          0
# 19           Каунт Бейсі             Breakfast Dance and Barbecue          0
# 20           Каунт Бейсі                            I Dig Dancers          0
# 21           Каунт Бейсі  Hoochie Coochie Man (Jimmy Smith album)          0
# 22           Каунт Бейсі                          Ella and Basie!          0
# 23           Каунт Бейсі                    Sing Along with Basie          0
# 24           Каунт Бейсі         The Greatest!! Count Basie Plays          0
# 25           Каунт Бейсі                          Back with Basie          0
# 26           Каунт Бейсі                   April in Paris (album)          0
# 27           Каунт Бейсі                       Count Basie Swings          0
# 28           Каунт Бейсі                 Metronome All-Stars 1956          0
# 29           Каунт Бейсі                 Jazz at the Philharmonic          0
# ...                  ...                                      ...        ...
# 2338539  Сабіна Сіммондс                       Isabelle Demongeot          0
# 2338540  Сабіна Сіммондс                                    Hu Na          0
# 2338541  Сабіна Сіммондс                     Svetlana Parkhomenko          0
# 2338542  Сабіна Сіммондс                           Stephanie Rehe          0
# 2338543  Сабіна Сіммондс                      Patricia Hy-Boulais          0
# 2338544  Сабіна Сіммондс                          Janine Thompson          0
# 2338545  Сабіна Сіммондс                         Belinda Cordwell          0
# 2338546  Сабіна Сіммондс                      Tine Scheuer-Larsen          0
# 2338547  Сабіна Сіммондс                              Silke Meier          0
# 2338548  Сабіна Сіммондс                        Philip Morris USA          0
# 2338549  Сабіна Сіммондс                             Louise Field          0
# 2338550  Сабіна Сіммондс                     Lesley Turner Bowrey          0
# 2338551  Сабіна Сіммондс                             Helen Kelesi          0
# 2338552  Сабіна Сіммондс                          Heather Ludloff          0
# 2338553  Сабіна Сіммондс                 Glossary of tennis terms          0
# 2338554  Сабіна Сіммондс                            Bettina Fulco          0
# 2338555  Сабіна Сіммондс                 Alexia Dechaume-Balleret          0
# 2338556  Сабіна Сіммондс                          Marianne Werdel          0
# 2338557  Сабіна Сіммондс                              Jenny Byrne          0
# 2338558  Сабіна Сіммондс                           Claudia Porwik          0
# 2338559  Сабіна Сіммондс                           Barbara Paulus          0
# 2338560  Сабіна Сіммондс                     Robin White (tennis)          0
# 2338561  Сабіна Сіммондс                              Lori McNeil          0
# 2338562  Сабіна Сіммондс                         Katerina Maleeva          0
# 2338563  Сабіна Сіммондс                           Judith Wiesner          0
# 2338564  Сабіна Сіммондс                             Elna Reinach          0
# 2338565  Сабіна Сіммондс                     UPI (disambiguation)          0
# 2338566  Сабіна Сіммондс                         Nathalie Tauziat          0
# 2338567  Сабіна Сіммондс                             Mercedes Paz          0
# 2338568  Сабіна Сіммондс                 University of California          0
#
# [2338569 rows x 3 columns]

# %%
with_BN_df = with_BN_df.reset_index(level=0, drop=True)

# %%
with_BN_df.shape
# Out:
# (2338569, 3)

# %%
# extract jaccard scores

# %%
all_results_scores = {}
all_results_list = [[]] * train_candidates.shape[0]
for i in range(train_candidates.shape[0]):
    if train_candidates['en_similar'][i] == '[]':
        all_results_scores[train_candidates['red_link_name'][i]] = []
        all_results_list[i] = []
    else:
        res = extract_score(train_candidates['en_similar'][i])
        all_results_scores[train_candidates['red_link_name'][i]] = res
        all_results_list[i] = res

# %%
len(all_results_scores)
# Out:
# 2518

# %%
df = pd.DataFrame.from_dict(all_results_scores, orient = 'index')

rl_with_score = df.stack().reset_index(level=0, drop=True).to_frame(name='jaccard_score')

# %%
rl_with_score = rl_with_score.reset_index(level=0, drop=True)

# %%
rl_with_score.shape
# Out:
# (2338569, 1)

# %%
df_2f = pd.concat([with_BN_df, rl_with_score], axis=1)

# %%
df_2f.head()
# Out:
#   red_link_name              candidate BN_results  jaccard_score
# 0   Каунт Бейсі  The Count Basie Story          0          0.081
# 1   Каунт Бейсі   The Atomic Mr. Basie          0          0.076
# 2   Каунт Бейсі        Basie in London          0          0.068
# 3   Каунт Бейсі             Basie Jazz          0          0.066
# 4   Каунт Бейсі          Basie (album)          0          0.066

# %%
df_2f.shape
# Out:
# (2338569, 4)

# %%
# add levenstein distance score

# %%
def calculate_norm_levenstein_df(row):
    red_link = str(row['red_link_name'])
    candidate = str(row['candidate'])
    abs_dist = levenshteinDistance(translit(red_link, 'uk', reversed=True), candidate)
    norm_dist = abs_dist/max(len(red_link), len(candidate))
    norm_dist = round(norm_dist, 3)
    return norm_dist

# %%
df_2f['levenstein_score'] = df_2f.apply(calculate_norm_levenstein_df, axis=1)

# %%
df_2f
# Out:
#            red_link_name                                candidate BN_results  \
# 0            Каунт Бейсі                    The Count Basie Story          0
# 1            Каунт Бейсі                     The Atomic Mr. Basie          0
# 2            Каунт Бейсі                          Basie in London          0
# 3            Каунт Бейсі                               Basie Jazz          0
# 4            Каунт Бейсі                            Basie (album)          0
# 5            Каунт Бейсі        Everyday I Have the Blues (album)          0
# 6            Каунт Бейсі                               The Count!          0
# 7            Каунт Бейсі          Golden Boy (Quincy Jones album)          0
# 8            Каунт Бейсі                Dance Session Album No. 2          0
# 9            Каунт Бейсі                   Count Basie at Newport          0
# 10           Каунт Бейсі                 One O'Clock Jump (album)          0
# 11           Каунт Бейсі                          I/We Had a Ball          0
# 12           Каунт Бейсі                        Kansas City Suite          0
# 13           Каунт Бейсі         Hall of Fame (Count Basie album)          0
# 14           Каунт Бейсі                      Basie One More Time          0
# 15           Каунт Бейсі                      This Time by Basie!          0
# 16           Каунт Бейсі              On My Way & Shoutin' Again!          0
# 17           Каунт Бейсі                            Dance Session          0
# 18           Каунт Бейсі                   Dance Along with Basie          0
# 19           Каунт Бейсі             Breakfast Dance and Barbecue          0
# 20           Каунт Бейсі                            I Dig Dancers          0
# 21           Каунт Бейсі  Hoochie Coochie Man (Jimmy Smith album)          0
# 22           Каунт Бейсі                          Ella and Basie!          0
# 23           Каунт Бейсі                    Sing Along with Basie          0
# 24           Каунт Бейсі         The Greatest!! Count Basie Plays          0
# 25           Каунт Бейсі                          Back with Basie          0
# 26           Каунт Бейсі                   April in Paris (album)          0
# 27           Каунт Бейсі                       Count Basie Swings          0
# 28           Каунт Бейсі                 Metronome All-Stars 1956          0
# 29           Каунт Бейсі                 Jazz at the Philharmonic          0
# ...                  ...                                      ...        ...
# 2338539  Сабіна Сіммондс                       Isabelle Demongeot          0
# 2338540  Сабіна Сіммондс                                    Hu Na          0
# 2338541  Сабіна Сіммондс                     Svetlana Parkhomenko          0
# 2338542  Сабіна Сіммондс                           Stephanie Rehe          0
# 2338543  Сабіна Сіммондс                      Patricia Hy-Boulais          0
# 2338544  Сабіна Сіммондс                          Janine Thompson          0
# 2338545  Сабіна Сіммондс                         Belinda Cordwell          0
# 2338546  Сабіна Сіммондс                      Tine Scheuer-Larsen          0
# 2338547  Сабіна Сіммондс                              Silke Meier          0
# 2338548  Сабіна Сіммондс                        Philip Morris USA          0
# 2338549  Сабіна Сіммондс                             Louise Field          0
# 2338550  Сабіна Сіммондс                     Lesley Turner Bowrey          0
# 2338551  Сабіна Сіммондс                             Helen Kelesi          0
# 2338552  Сабіна Сіммондс                          Heather Ludloff          0
# 2338553  Сабіна Сіммондс                 Glossary of tennis terms          0
# 2338554  Сабіна Сіммондс                            Bettina Fulco          0
# 2338555  Сабіна Сіммондс                 Alexia Dechaume-Balleret          0
# 2338556  Сабіна Сіммондс                          Marianne Werdel          0
# 2338557  Сабіна Сіммондс                              Jenny Byrne          0
# 2338558  Сабіна Сіммондс                           Claudia Porwik          0
# 2338559  Сабіна Сіммондс                           Barbara Paulus          0
# 2338560  Сабіна Сіммондс                     Robin White (tennis)          0
# 2338561  Сабіна Сіммондс                              Lori McNeil          0
# 2338562  Сабіна Сіммондс                         Katerina Maleeva          0
# 2338563  Сабіна Сіммондс                           Judith Wiesner          0
# 2338564  Сабіна Сіммондс                             Elna Reinach          0
# 2338565  Сабіна Сіммондс                     UPI (disambiguation)          0
# 2338566  Сабіна Сіммондс                         Nathalie Tauziat          0
# 2338567  Сабіна Сіммондс                             Mercedes Paz          0
# 2338568  Сабіна Сіммондс                 University of California          0
#
#          jaccard_score  levenstein_score
# 0                0.081             0.714
# 1                0.076             0.800
# 2                0.068             0.867
# 3                0.066             0.818
# 4                0.066             0.846
# 5                0.065             0.848
# 6                0.063             1.000
# 7                0.063             0.871
# 8                0.063             0.800
# 9                0.062             0.727
# 10               0.061             0.917
# 11               0.059             0.867
# 12               0.051             0.765
# 13               0.051             0.781
# 14               0.051             0.737
# 15               0.050             0.842
# 16               0.050             0.852
# 17               0.049             0.615
# 18               0.049             0.727
# 19               0.049             0.821
# 20               0.048             0.846
# 21               0.048             0.923
# 22               0.048             0.667
# 23               0.047             0.762
# 24               0.046             0.781
# 25               0.046             0.667
# 26               0.045             0.909
# 27               0.043             0.611
# 28               0.041             0.875
# 29               0.038             0.792
# ...                ...               ...
# 2338539          0.007             0.722
# 2338540          0.007             0.933
# 2338541          0.006             0.700
# 2338542          0.006             0.800
# 2338543          0.006             0.684
# 2338544          0.006             0.667
# 2338545          0.006             0.750
# 2338546          0.005             0.842
# 2338547          0.005             0.867
# 2338548          0.005             0.941
# 2338549          0.005             0.733
# 2338550          0.005             0.900
# 2338551          0.005             0.867
# 2338552          0.005             0.867
# 2338553          0.005             0.833
# 2338554          0.005             0.733
# 2338555          0.005             0.875
# 2338556          0.004             0.800
# 2338557          0.004             0.800
# 2338558          0.004             0.867
# 2338559          0.004             0.733
# 2338560          0.003             0.700
# 2338561          0.003             0.867
# 2338562          0.003             0.750
# 2338563          0.003             0.733
# 2338564          0.003             0.800
# 2338565          0.002             0.800
# 2338566          0.002             0.938
# 2338567          0.002             1.000
# 2338568          0.001             0.833
#
# [2338569 rows x 5 columns]

# %%
df_2f.to_csv(PATH_TO_DATA_RL+'train_red_links_uk_with_features.csv', header=True, index=False)
