# %%
import pandas as pd

import numpy as np
from numpy import nan as Nan

import math

import transliterate
from transliterate import translit, get_available_language_codes

# %%
def extract_list(s):
    return [x.split(',')[1].strip("', ,\"") for x in s[2:-2].split('), (')]

def extract_score(s):
    return [float(x.split(',')[0].strip("', ,\"")) for x in s[2:-2].split('), (')]

def levenshteinDistance(s1, s2):
    if len(s1) > len(s2):
        s1, s2 = s2, s1

    distances = range(len(s1) + 1)
    for i2, c2 in enumerate(s2):
        distances_ = [i2+1]
        for i1, c1 in enumerate(s1):
            if c1 == c2:
                distances_.append(distances[i1])
            else:
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
        distances = distances_
    return distances[-1]

# %%
PATH_TO_DATA = '/media/andrii/earth/Katia/CS_MasterThesis/data/'
PATH_TO_DATA_RL = '/media/andrii/earth/Katia/CS_MasterThesis/data/ukwiki/uk_red_links/'
PATH_TO_DATA_UK = '/media/andrii/earth/Katia/CS_MasterThesis/data/ukwiki/ukwiki_20180920/'
PATH_TO_DATA_EN = '/media/andrii/earth/Katia/CS_MasterThesis/data/ukwiki/enwiki_20180920/'

# %%
uk_redlinks_sample = pd.read_csv(PATH_TO_DATA_RL+'df_sample_red_links_uk.csv', encoding = 'UTF-8')

# %%
uk_redlinks_sample
# Out:
#                                           red_link_name
# 0                                           Каунт Бейсі
# 1                                              аль-Каїм
# 2                                              королева
# 3                                         Prentice Hall
# 4                                              Tokar.ua
# 5     Monthly Notices of the Royal Astronomical Society
# 6                                    Світ (видавництво)
# 7                               Дубович Іван Андрійович
# 8                                помірні повітряні маси
# 9                          Доповідь про торгівлю людьми
# 10    Управління з моніторингу та боротьби з торгівл...
# 11    Управління з моніторингу та боротьби з торгівл...
# 12                          Руденко Ірина Станіславівна
# 13                         Радченко Вероніка Вікторівна
# 14                        Вакуленко Олена Володимирівна
# 15                          Скуратович Олег Ярославович
# 16                                Чанцева Ніна Іванівна
# 17      Головне управління геодезії та картографії СРСР
# 18                                         Random House
# 19                                     Simon & Schuster
# 20                                    Панчакутек Юпанкі
# 21                                                Земун
# 22                            Східний тюркський каганат
# 23                                  Приморська Хорватія
# 24                                           Раштакурти
# 25                                           моніторинг
# 26                        Купрієнко Сергій Анатолійович
# 27                             Талах Віктор Миколайович
# 28                                             Керкраде
# 29                                 Daylight saving time
# ...                                                 ...
# 3164                                Ніколе Мунс-Ягерман
# 3165                                       Андреа Леанд
# 3166                                      Беверлі Бовіс
# 3167                         Сенді Коллінз (тенісистка)
# 3168                            Луїс Аллен (тенісистка)
# 3169                                        Лаура Аррая
# 3170                                       С'юзен Слоун
# 3171                                   Пінат Луї Гарпер
# 3172                                       Пілар Васкес
# 3173                                              Ху На
# 3174                                       Кім Стейнмец
# 3175                                         Пем Кеселі
# 3176                                        Ліса Бондер
# 3177                                        Іноуе Ецуко
# 3178                                         Ева Крапль
# 3179                                      Сабрина Голеш
# 3180                                        Террі Фелпс
# 3181                                         Селін Коен
# 3182                            Венді Вайт (тенісистка)
# 3183                                     Тіна Мочідзукі
# 3184                                         Нейже Діас
# 3185                                       Карен Шимпер
# 3186                                      Мішелл Торрес
# 3187                                      Лі Антонопліс
# 3188                                     Мері-Лу П'ятек
# 3189                                   Патрісія Медрадо
# 3190                                    С'юзен Маскарін
# 3191                                      Алісія Молтон
# 3192                                    Сабіна Сіммондс
# 3193                                         Latin Rite
#
# [3194 rows x 1 columns]

# %%
# get train and test samples
msk = np.random.rand(len(uk_redlinks_sample)) < 0.8
train = uk_redlinks_sample[msk]
test = uk_redlinks_sample[~msk]

print('train length =', len(train))
print('test length =', len(test))
# Out:
# train length = 2557
# test length = 637

# %%
# save train and test sets to files
train.to_csv(PATH_TO_DATA_RL+'train_red_links_uk.csv', header=True, index=False)
test.to_csv(PATH_TO_DATA_RL+'test_red_links_uk.csv', header=True, index=False)

# %%
# read train and test samples
train_sample = pd.read_csv(PATH_TO_DATA_RL+'train_red_links_uk.csv', encoding = 'UTF-8')
test_sample = pd.read_csv(PATH_TO_DATA_RL+'test_red_links_uk.csv', encoding = 'UTF-8')

# %% [markdown]
# ## Table for test set

# %%
test_list = test_sample['red_link_name'].tolist()

# %%
candidates = pd.read_csv(PATH_TO_DATA_RL+'uk_red_links_results_all_candidates.csv', encoding = 'UTF-8')

# %%
test_candidates = pd.merge(test_sample, candidates, how='inner', left_on='red_link_name', right_on='red_link_name')

# %%
all_results = {}
all_results_list = [[]] * test_candidates.shape[0]
for i in range(test_candidates.shape[0]):
    if test_candidates['en_similar'][i] == '[]':
        all_results[test_candidates['red_link_name'][i]] = []
        all_results_list[i] = []
    else:
        res = extract_list(test_candidates['en_similar'][i])
        all_results[test_candidates['red_link_name'][i]] = res
        all_results_list[i] = res

# %%
len(all_results.keys())
# Out:
# 637

# %%
df = pd.DataFrame.from_dict(all_results, orient = 'index')

rl_with_cand = df.stack().reset_index(level=1, drop=True).to_frame(name='candidate')

# %%
rl_with_cand['red_link_name'] = rl_with_cand.index

# %%
rl_with_cand
# Out:
#                                        candidate  red_link_name
# аль-Каїм                       Ahmad al-Muqtadir       аль-Каїм
# аль-Каїм                               Cai Xiang       аль-Каїм
# аль-Каїм                                  Odo II       аль-Каїм
# аль-Каїм                        Judith of Swabia       аль-Каїм
# аль-Каїм                 Eudokia Makrembolitissa       аль-Каїм
# аль-Каїм                             Pontificate       аль-Каїм
# аль-Каїм                Kadam (Tibetan Buddhism)       аль-Каїм
# аль-Каїм       Common year starting on Wednesday       аль-Каїм
# аль-Каїм        Common year starting on Saturday       аль-Каїм
# аль-Каїм         Common year starting on Tuesday       аль-Каїм
# аль-Каїм          Common year starting on Monday       аль-Каїм
# аль-Каїм          Common year starting on Friday       аль-Каїм
# аль-Каїм                         Bertha of Savoy       аль-Каїм
# аль-Каїм                      Constance of Arles       аль-Каїм
# аль-Каїм          Leap year starting on Thursday       аль-Каїм
# аль-Каїм           Leap year starting on Tuesday       аль-Каїм
# аль-Каїм            Leap year starting on Sunday       аль-Каїм
# аль-Каїм          Leap year starting on Saturday       аль-Каїм
# аль-Каїм        Common year starting on Thursday       аль-Каїм
# аль-Каїм          Common year starting on Sunday       аль-Каїм
# аль-Каїм                        Urraca of Zamora       аль-Каїм
# аль-Каїм                                 Ulric I       аль-Каїм
# аль-Каїм                            Tihany Abbey       аль-Каїм
# аль-Каїм                            Theodoric II       аль-Каїм
# аль-Каїм            Taxation in medieval England       аль-Каїм
# аль-Каїм                                 Sokkate       аль-Каїм
# аль-Каїм                         Shalu Monastery       аль-Каїм
# аль-Каїм                              Samshvilde       аль-Каїм
# аль-Каїм                         Sakya Monastery       аль-Каїм
# аль-Каїм                        Primas Germaniae       аль-Каїм
# ...                                          ...            ...
# Лі Антонопліс                   Cathy Caverzasio  Лі Антонопліс
# Лі Антонопліс                     Shaun Stafford  Лі Антонопліс
# Лі Антонопліс                   Meredith McGrath  Лі Антонопліс
# Лі Антонопліс                      Maya Kidowaki  Лі Антонопліс
# Лі Антонопліс                    Marie Pinterova  Лі Антонопліс
# Лі Антонопліс                   Maria Strandlund  Лі Антонопліс
# Лі Антонопліс                    Sandra Cecchini  Лі Антонопліс
# Лі Антонопліс                    Natalia Egorova  Лі Антонопліс
# Лі Антонопліс                     Ivanna Madruga  Лі Антонопліс
# Лі Антонопліс            Brenda Schultz-McCarthy  Лі Антонопліс
# Лі Антонопліс           Alexia Dechaume-Balleret  Лі Антонопліс
# Лі Антонопліс                      Maureen Drake  Лі Антонопліс
# Лі Антонопліс                     Judith Wiesner  Лі Антонопліс
# Лі Антонопліс                 Isabelle Demongeot  Лі Антонопліс
# Лі Антонопліс                      Debbie Graham  Лі Антонопліс
# Лі Антонопліс                      Petra Schwarz  Лі Антонопліс
# Лі Антонопліс                       Lise Gregory  Лі Антонопліс
# Лі Антонопліс                         Linda Wild  Лі Антонопліс
# Лі Антонопліс                       Rene Simpson  Лі Антонопліс
# Лі Антонопліс                    Manon Bollegraf  Лі Антонопліс
# Лі Антонопліс           Glossary of tennis terms  Лі Антонопліс
# Лі Антонопліс                      Wang Shi-ting  Лі Антонопліс
# Лі Антонопліс         Natalia Medvedeva (tennis)  Лі Антонопліс
# Лі Антонопліс                   Nathalie Tauziat  Лі Антонопліс
# Лі Антонопліс                     Kristine Kunce  Лі Антонопліс
# Лі Антонопліс                       Erika deLone  Лі Антонопліс
# Лі Антонопліс                     Amanda Coetzer  Лі Антонопліс
# Лі Антонопліс               UPI (disambiguation)  Лі Антонопліс
# Лі Антонопліс                   Sabine Appelmans  Лі Антонопліс
# Лі Антонопліс               The Arizona Republic  Лі Антонопліс
#
# [574749 rows x 2 columns]

# %%
# add BabelNet results
BN_results = pd.read_csv(PATH_TO_DATA_RL+'BN_ukredlinks_wiki_evaluated.csv', encoding = 'UTF-8')

# %%
BN_results.head()
# Out:
#    red link name                                              EN BN  \
# 0    Каунт Бейсі                                                NaN
# 1       аль-Каїм                                  Al-Qa'im (caliph)
# 2       королева  gyne, monarch, queen regnant, queen (chess), T...
# 3  Prentice Hall                                                NaN
# 4       Tokar.ua                                                NaN
#
#                                EN if else Evaluation  \
# 0                             Count Basie         FN
# 1  also Al-Qa'im (town), Al-Qa'im (Cairo)         FP
# 2                                     NaN         FP
# 3                           Prentice Hall         FN
# 4                                     NaN         TN
#
#                                              Remarks
# 0                                                NaN
# 1  article in UK Wiki exists. Impossible to know ...
# 2                   right item not first in the list
# 3                                                NaN
# 4                                                NaN

# %%
df_with_BN = pd.merge(rl_with_cand, BN_results, how='inner', left_on='red_link_name', right_on='red link name')

# %%
df_with_BN = df_with_BN[['red_link_name','candidate', 'EN BN']]

# %%
df_with_BN.head()
# Out:
#   red_link_name                candidate              EN BN
# 0      аль-Каїм        Ahmad al-Muqtadir  Al-Qa'im (caliph)
# 1      аль-Каїм                Cai Xiang  Al-Qa'im (caliph)
# 2      аль-Каїм                   Odo II  Al-Qa'im (caliph)
# 3      аль-Каїм         Judith of Swabia  Al-Qa'im (caliph)
# 4      аль-Каїм  Eudokia Makrembolitissa  Al-Qa'im (caliph)

# %%
bn_results = []
for index, row in df_with_BN.iterrows():
    bn_result = row['candidate'] == row['EN BN']
    bn_results.append(bn_result)

# %%
BN_df = pd.DataFrame(bn_results)

# %%
with_BN_df = pd.concat([df_with_BN, BN_df], axis=1)
with_BN_df.columns = ['red_link_name', 'candidate', 'EN BN', 'BN_results']
with_BN_df = with_BN_df[['red_link_name', 'candidate', 'BN_results']]

# %%
with_BN_df['BN_results'] = with_BN_df['BN_results'].replace(False, 0)

# %%
with_BN_df['BN_results'] = with_BN_df['BN_results'].replace(True, 1)

# %%
with_BN_df
# Out:
#         red_link_name                                          candidate  \
# 0            Tokar.ua  List of virtual communities with more than 100...
# 1            Tokar.ua                    Solar Energy Generating Systems
# 2            Tokar.ua                           Stand-alone power system
# 3            Tokar.ua                             Construction Equipment
# 4            Tokar.ua                                      Solar tracker
# 5            Tokar.ua            Comparison of instant messaging clients
# 6            Tokar.ua                        Comparison of VoIP software
# 7            Tokar.ua                                        Yahoo! Tech
# 8            Tokar.ua                                        Trombe wall
# 9            Tokar.ua               Trinidadian and Tobagonian Americans
# 10           Tokar.ua                                Total Communication
# 11           Tokar.ua                                   Tongan Americans
# 12           Tokar.ua                               Tokyu Kogyo Kurogane
# 13           Tokar.ua                     Terrorist Surveillance Program
# 14           Tokar.ua                                         Solar lamp
# 15           Tokar.ua                                              Shtil
# 16           Tokar.ua                                 Shinichiro Sakurai
# 17           Tokar.ua                                         Ralph Budd
# 18           Tokar.ua              Public Policy Institute of California
# 19           Tokar.ua                                     Nissan R'nessa
# 20           Tokar.ua                                     Nissan Presage
# 21           Tokar.ua                                   Nassella pulchra
# 22           Tokar.ua                                     Macintosh IIsi
# 23           Tokar.ua                             List of whistleblowers
# 24           Tokar.ua               List of solar thermal power stations
# 25           Tokar.ua                     List of orbital launch systems
# 26           Tokar.ua   List of most-downloaded Google Play applications
# 27           Tokar.ua       List of films featuring powered exoskeletons
# 28           Tokar.ua                                      Lionel Whitby
# 29           Tokar.ua                                       Jet injector
# ...               ...                                                ...
# 563225  Алісія Молтон                                    Sandra Cecchini
# 563226  Алісія Молтон                                    Natalia Egorova
# 563227  Алісія Молтон                                      Laura Garrone
# 563228  Алісія Молтон                                        Elly Hakami
# 563229  Алісія Молтон                                     Wiltrud Probst
# 563230  Алісія Молтон                                         Valda Lake
# 563231  Алісія Молтон                                   Sandra Wasserman
# 563232  Алісія Молтон                                         Ronni Reis
# 563233  Алісія Молтон                                     Linda Ferrando
# 563234  Алісія Молтон                                       Glynis Coles
# 563235  Алісія Молтон                                         Penny Barg
# 563236  Алісія Молтон                                  Philip Morris USA
# 563237  Алісія Молтон                               Nicole Muns-Jagerman
# 563238  Алісія Молтон                                   Nathalie Tauziat
# 563239  Алісія Молтон                               Michelle Jaggard-Lai
# 563240  Алісія Молтон                                      Bettina Fulco
# 563241  Алісія Молтон                           Alexia Dechaume-Balleret
# 563242  Алісія Молтон                                    Manon Bollegraf
# 563243  Алісія Молтон                                   Julie Richardson
# 563244  Алісія Молтон                                      Laura Golarsa
# 563245  Алісія Молтон                                     Judith Wiesner
# 563246  Алісія Молтон                                  Jill Hetherington
# 563247  Алісія Молтон                           Glossary of tennis terms
# 563248  Алісія Молтон                                       Ann Grossman
# 563249  Алісія Молтон                               UPI (disambiguation)
# 563250  Алісія Молтон                                      Katrina Adams
# 563251  Алісія Молтон                            Brenda Schultz-McCarthy
# 563252  Алісія Молтон                                        Amy Frazier
# 563253  Алісія Молтон                           University of California
# 563254  Алісія Молтон                               The Arizona Republic
#
#        BN_results
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False
# 10          False
# 11          False
# 12          False
# 13          False
# 14          False
# 15          False
# 16          False
# 17          False
# 18          False
# 19          False
# 20          False
# 21          False
# 22          False
# 23          False
# 24          False
# 25          False
# 26          False
# 27          False
# 28          False
# 29          False
# ...           ...
# 563225      False
# 563226      False
# 563227      False
# 563228      False
# 563229      False
# 563230      False
# 563231      False
# 563232      False
# 563233      False
# 563234      False
# 563235      False
# 563236      False
# 563237      False
# 563238      False
# 563239      False
# 563240      False
# 563241      False
# 563242      False
# 563243      False
# 563244      False
# 563245      False
# 563246      False
# 563247      False
# 563248      False
# 563249      False
# 563250      False
# 563251      False
# 563252      False
# 563253      False
# 563254      False
#
# [563255 rows x 3 columns]

# %%
with_BN_df = with_BN_df.reset_index(level=0, drop=True)

# %%
# extract jaccard scores

# %%
all_results_scores = {}
all_results_list = [[]] * test_candidates.shape[0]
for i in range(test_candidates.shape[0]):
    if test_candidates['en_similar'][i] == '[]':
        all_results_scores[test_candidates['red_link_name'][i]] = []
        all_results_list[i] = []
    else:
        res = extract_score(test_candidates['en_similar'][i])
        all_results_scores[test_candidates['red_link_name'][i]] = res
        all_results_list[i] = res

# %%
len(all_results_scores)
# Out:
# 625

# %%
df = pd.DataFrame.from_dict(all_results_scores, orient = 'index')

rl_with_score = df.stack().reset_index(level=0, drop=True).to_frame(name='jaccard_score')

# %%
rl_with_score = rl_with_score.reset_index(level=0, drop=True)

# %%
df_2f = pd.concat([with_BN_df, rl_with_score], axis=1)

# %%
df_2f.head()
# Out:
#   red_link_name                                          candidate BN_results  \
# 0      Tokar.ua  List of virtual communities with more than 100...      False
# 1      Tokar.ua                    Solar Energy Generating Systems      False
# 2      Tokar.ua                           Stand-alone power system      False
# 3      Tokar.ua                             Construction Equipment      False
# 4      Tokar.ua                                      Solar tracker      False
#
#    jaccard_score
# 0          0.050
# 1          0.032
# 2          0.027
# 3          0.025
# 4          0.023

# %%
# add levenstein distance score

# %%
def calculate_levendtein_df(row):
    return -levenshteinDistance(translit(row['red_link_name'], 'uk', reversed=True), row['candidate'])

# %%
df_2f['levenstein_score'] = df_2f.apply(calculate_levendtein_df, axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-fca88ed70212> in <module>()
# ----> 1 df_2f['levenstein_score'] = df_2f.apply(calculate_levendtein_df, axis=1)
#
# /home/andrii/apps/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# /home/andrii/apps/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4246             try:
#    4247                 for i, v in enumerate(series_gen):
# -> 4248                     results[i] = func(v)
#    4249                     keys.append(v.name)
#    4250             except Exception as e:
#
# <ipython-input-37-e4a6709709f5> in calculate_levendtein_df(row)
#       1 def calculate_levendtein_df(row):
# ----> 2     return -levenshteinDistance(translit(row['red_link_name'], 'uk', reversed=True), row['candidate'])
#
# /home/andrii/apps/anaconda3/lib/python3.6/site-packages/transliterate/utils.py in translit(value, language_code, reversed, strict)
#      92
#      93     language_pack = cls()
# ---> 94     return language_pack.translit(value, reversed=reversed, strict=strict)
#      95
#      96
#
# /home/andrii/apps/anaconda3/lib/python3.6/site-packages/transliterate/base.py in translit(self, value, reversed, strict, fail_silently)
#     195             # Handling reversed specific translations (one side only).
#     196             if self.reversed_specific_mapping:
# --> 197                 value = value.translate(
#     198                     self.reversed_specific_translation_table
#     199                 )
#
# AttributeError: ("'float' object has no attribute 'translate'", 'occurred at index 563255')

# %%
df_3f = df_2f
df_3f
